# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import theano
import matplotlib
from matplotlib import pyplot
from matplotlib import cm
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg' 
matplotlib.rcParams['figure.figsize'] = (12.0, 1.0)
matplotlib.rcParams['font.size'] = 7

import matplotlib.lines as mlines
import seaborn
seaborn.set_style('darkgrid')
import logging 
log = logging.getLogger()
log.setLevel('DEBUG')
# Out:
# Using gpu device 0: GeForce GTX 780 (CNMeM is disabled)

# %% [markdown]
# # Experiment Tutorial

# %% [markdown]
# In this tutorial, we will run an experiment on the BCI Competition IV dataset.
# We will look at how to run a normal experiment and how to train over smaller windows cut out of the trials.
#
# We have these four steps for the experiment:
#
# 1. load the dataset
# 2. create the layers
# 3. configure the experiment
# 4. run the experiment
#
# We assume you have the BCI Competition Data under ```data/bci-competition-iv/2a-combined/```.

# %% [markdown]
# ## Load the dataset
#
# When loading the dataset, we have the following choiches to make:
#
# * trial window => segment_ival
# * what preprocessings to apply to the continuous signal, e.g. resampling, highpass etc.
# * what sensors to use (not implemented atm for BCI competition set, since there are only 22 EEG sensors anyways :))

# %%
from braindecode.datasets.signal_processor import SignalProcessor
from braindecode.datasets.loaders import BCICompetition4Set2A
from braindecode.datasets.raw import CleanSignalMatrix
from braindecode.datahandling.batch_iteration import WindowsIterator
from braindecode.veganlasagne.monitors import WindowMisclassMonitor
from braindecode.mywyrm.clean import NoCleaner
from braindecode.mywyrm.processing import resample_cnt, highpass_cnt

signal_processor = SignalProcessor(set_loader=BCICompetition4Set2A(
            filename="data/bci-competition-iv/2a-combined/A03TE.mat"),
    segment_ival=[0, 4000], 
    cnt_preprocessors=[[resample_cnt,dict(newfs=150)],
                       [highpass_cnt, dict(low_cut_off_hz=0.5)]])

dataset = CleanSignalMatrix(cleaner=NoCleaner(), 
                                  signal_processor=signal_processor, 
                                  sensor_names='all')
dataset.load()
# Out:
# INFO:braindecode.datasets.raw:Loading set...
# INFO:braindecode.datasets.raw:Cleaning set...
# INFO:braindecode.datasets.raw:Preprocessing set...
# INFO:braindecode.datasets.raw:Loaded clean data with shape (576, 600, 22).
# INFO:braindecode.datasets.raw:Loaded dataset with shape: (576, 22, 600, 1)

# %% [markdown]
# ## Create Layers
#
# Here we will use the raw net, we set the input shape correctly from the loaded dataset. Note that we give names to the layers with weights, we need them later to constrain their norms.

# %%
import lasagne
from numpy.random import RandomState
from lasagne.layers import DenseLayer,DropoutLayer,Conv2DLayer, DimshuffleLayer, InputLayer, NonlinearityLayer
from braindecode.veganlasagne.layers import Conv2DAllColsLayer
from braindecode.veganlasagne.pool import SumPool2dLayer
lasagne.random.set_rng(RandomState(9859295))
in_shape = list(dataset.get_topological_view().shape)
in_shape[0] = None # to allow arbitrary sizes of batches
in_layer = InputLayer(shape=in_shape)
network = DimshuffleLayer(incoming= in_layer, pattern=[0, 3, 2, 1])
network = Conv2DLayer(incoming=network, num_filters=40,
    filter_size=[15, 1], nonlinearity=lasagne.nonlinearities.identity, name='time_conv')
network = DropoutLayer(incoming=network, p=0.5)
network = Conv2DAllColsLayer(incoming=network, num_filters=40,
    filter_size=[1, -1], nonlinearity=theano.tensor.sqr, name='spat_conv')
network = SumPool2dLayer(incoming=network, pool_size=[50, 1],
    stride=[10, 1], mode='average_exc_pad')
network = NonlinearityLayer(incoming=network, 
    nonlinearity=theano.tensor.log)
network = DropoutLayer(incoming=network, p=0.5)
network = DenseLayer(incoming=network,
    num_units=4, nonlinearity=lasagne.nonlinearities.softmax, name='final_dense')

# %% [markdown]
# ## Configure the Experiment

# %% [markdown]
# ### Dataset Splitting

# %% [markdown]
# We first look at the how to split our dataset into train, valid and test set. We split this dataset at a fixed trial, nr. 288, into train and test. Since the dataset has 576 trials, this exactly splits it into half training and half test as in the original BCI Competition.
# We use 20% of the **training trials** as our validation set. The validation trials are always at the end of the training set.

# %%
from braindecode.datahandling.splitters import FixedTrialSplitter
dataset_splitter=FixedTrialSplitter(n_train_trials=288, valid_set_fraction=0.2)

# %% [markdown]
# ### Dataset Preprocessing

# %% [markdown]
# We preprocess our dataset along the channel axis. We use online standardization so it could also be applied in the same way for an online experiment.

# %%
from braindecode.datahandling.preprocessing import OnlineAxiswiseStandardize
preprocessor = OnlineAxiswiseStandardize(axis=['c', 1]) # the 1 is not important as the 1 dim (form bc01) is empty...

# %% [markdown]
# ### Batch Iteration

# %% [markdown]
# We iterate over balanced batches, so batches are gauranteed to have a maximum size difference of 1. The way this is implemented, batches can get slightly bigger than the given batch size.

# %%
from braindecode.datahandling.batch_iteration import BalancedBatchIterator
dataset_iterator = BalancedBatchIterator(batch_size=60)

# %% [markdown]
# ### Loss and Updates

# %% [markdown]
# Our loss is the categorical cross entropy and updates will be computed using Adam.
# We will norm constraints, that means the units will be constrained to not have a larger sum of squares than specified.

# %%
from braindecode.veganlasagne.update_modifiers import MaxNormConstraint
updates_var_func=lasagne.updates.adam
loss_var_func= lasagne.objectives.categorical_crossentropy

updates_modifier = MaxNormConstraint({
            'time_conv': 2.0,
            'spat_conv': 2.0,
            'final_dense': 0.5})

# %% [markdown]
# ### Stopping and Monitors

# %% [markdown]
# Finally, we have to decide for a stopping and what values to monitor. We monitor loss and misclass (actually we always have to monitor them for the experiment to work) as well as the runtime per epoch.
# For stopping, we stop after 10 epochs.

# %%
from braindecode.veganlasagne.monitors import LossMonitor, MisclassMonitor, RuntimeMonitor
from braindecode.veganlasagne.stopping import MaxEpochs
from braindecode.experiments.experiment import Experiment
stop_criterion = MaxEpochs(num_epochs=20)
monitors=[LossMonitor(), MisclassMonitor(), RuntimeMonitor()]

exp = Experiment(network, dataset, dataset_splitter, preprocessor,
          dataset_iterator, loss_var_func, updates_var_func, updates_modifier, monitors, stop_criterion)

# %% [markdown]
# ## Run the Experiment

# %% [markdown]
# We setup the experiment and run it.

# %%
exp.setup()
exp.run()
# Out:
# INFO:braindecode.experiments.experiment:Layers...
# INFO:braindecode.experiments.experiment:InputLayer
# INFO:braindecode.experiments.experiment:[None, 22, 600, 1]
# INFO:braindecode.experiments.experiment:DimshuffleLayer
# INFO:braindecode.experiments.experiment:(None, 1, 600, 22)
# INFO:braindecode.experiments.experiment:Conv2DLayer
# INFO:braindecode.experiments.experiment:(None, 40, 586, 22)
# INFO:braindecode.experiments.experiment:DropoutLayer
# INFO:braindecode.experiments.experiment:(None, 40, 586, 22)
# INFO:braindecode.experiments.experiment:Conv2DAllColsLayer
# INFO:braindecode.experiments.experiment:(None, 40, 586, 1)
# INFO:braindecode.experiments.experiment:SumPool2dLayer
# INFO:braindecode.experiments.experiment:(None, 40, 54, 1)
# INFO:braindecode.experiments.experiment:NonlinearityLayer
# INFO:braindecode.experiments.experiment:(None, 40, 54, 1)
# INFO:braindecode.experiments.experiment:DropoutLayer
# INFO:braindecode.experiments.experiment:(None, 40, 54, 1)
# INFO:braindecode.experiments.experiment:DenseLayer
# INFO:braindecode.experiments.experiment:(None, 4)
# INFO:braindecode.experiments.experiment:Create theano functions...
# INFO:braindecode.veganlasagne.update_modifiers:Constraining time_conv to norm 2.00
# INFO:braindecode.veganlasagne.update_modifiers:Constraining spat_conv to norm 2.00
# INFO:braindecode.veganlasagne.update_modifiers:Constraining final_dense to norm 0.50
# INFO:braindecode.experiments.experiment:Done.
# INFO:braindecode.experiments.experiment:Run until first stop...
# INFO:braindecode.experiments.experiment:Split/Preprocess datasets...
# INFO:braindecode.experiments.experiment:...Done
# INFO:braindecode.experiments.experiment:Epoch 0
# INFO:braindecode.experiments.experiment:train_loss           1.64055
# INFO:braindecode.experiments.experiment:valid_loss           1.69265
# INFO:braindecode.experiments.experiment:test_loss            1.73310
# INFO:braindecode.experiments.experiment:train_misclass       0.75325
# INFO:braindecode.experiments.experiment:valid_misclass       0.68421
# INFO:braindecode.experiments.experiment:test_misclass        0.78125
# INFO:braindecode.experiments.experiment:runtime              0.00000
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.684211
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.167953 seconds
# INFO:braindecode.experiments.experiment:Epoch 1
# INFO:braindecode.experiments.experiment:train_loss           1.41430
# INFO:braindecode.experiments.experiment:valid_loss           1.39022
# INFO:braindecode.experiments.experiment:test_loss            1.37830
# INFO:braindecode.experiments.experiment:train_misclass       0.75758
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.73958
# INFO:braindecode.experiments.experiment:runtime              0.29931
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.153764 seconds
# INFO:braindecode.experiments.experiment:Epoch 2
# INFO:braindecode.experiments.experiment:train_loss           1.67874
# INFO:braindecode.experiments.experiment:valid_loss           1.64501
# INFO:braindecode.experiments.experiment:test_loss            1.54449
# INFO:braindecode.experiments.experiment:train_misclass       0.69264
# INFO:braindecode.experiments.experiment:valid_misclass       0.75439
# INFO:braindecode.experiments.experiment:test_misclass        0.72917
# INFO:braindecode.experiments.experiment:runtime              0.27404
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.154648 seconds
# INFO:braindecode.experiments.experiment:Epoch 3
# INFO:braindecode.experiments.experiment:train_loss           1.86951
# INFO:braindecode.experiments.experiment:valid_loss           1.86406
# INFO:braindecode.experiments.experiment:test_loss            1.68703
# INFO:braindecode.experiments.experiment:train_misclass       0.68831
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.72569
# INFO:braindecode.experiments.experiment:runtime              0.27081
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.153984 seconds
# INFO:braindecode.experiments.experiment:Epoch 4
# INFO:braindecode.experiments.experiment:train_loss           1.95696
# INFO:braindecode.experiments.experiment:valid_loss           1.90338
# INFO:braindecode.experiments.experiment:test_loss            1.70710
# INFO:braindecode.experiments.experiment:train_misclass       0.69697
# INFO:braindecode.experiments.experiment:valid_misclass       0.75439
# INFO:braindecode.experiments.experiment:test_misclass        0.74306
# INFO:braindecode.experiments.experiment:runtime              0.27000
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.153647 seconds
# INFO:braindecode.experiments.experiment:Epoch 5
# INFO:braindecode.experiments.experiment:train_loss           2.38657
# INFO:braindecode.experiments.experiment:valid_loss           2.32374
# INFO:braindecode.experiments.experiment:test_loss            2.01722
# INFO:braindecode.experiments.experiment:train_misclass       0.74026
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.75347
# INFO:braindecode.experiments.experiment:runtime              0.26954
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.153508 seconds
# INFO:braindecode.experiments.experiment:Epoch 6
# INFO:braindecode.experiments.experiment:train_loss           3.11164
# INFO:braindecode.experiments.experiment:valid_loss           2.97648
# INFO:braindecode.experiments.experiment:test_loss            2.51104
# INFO:braindecode.experiments.experiment:train_misclass       0.74459
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.75347
# INFO:braindecode.experiments.experiment:runtime              0.26948
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.153743 seconds
# INFO:braindecode.experiments.experiment:Epoch 7
# INFO:braindecode.experiments.experiment:train_loss           3.65973
# INFO:braindecode.experiments.experiment:valid_loss           3.37246
# INFO:braindecode.experiments.experiment:test_loss            2.72375
# INFO:braindecode.experiments.experiment:train_misclass       0.74459
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.75000
# INFO:braindecode.experiments.experiment:runtime              0.26938
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.154108 seconds
# INFO:braindecode.experiments.experiment:Epoch 8
# INFO:braindecode.experiments.experiment:train_loss           3.79708
# INFO:braindecode.experiments.experiment:valid_loss           3.50986
# INFO:braindecode.experiments.experiment:test_loss            2.70767
# INFO:braindecode.experiments.experiment:train_misclass       0.74459
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.73958
# INFO:braindecode.experiments.experiment:runtime              0.26940
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.153242 seconds
# INFO:braindecode.experiments.experiment:Epoch 9
# INFO:braindecode.experiments.experiment:train_loss           3.89535
# INFO:braindecode.experiments.experiment:valid_loss           3.72719
# INFO:braindecode.experiments.experiment:test_loss            2.81585
# INFO:braindecode.experiments.experiment:train_misclass       0.74459
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.73958
# INFO:braindecode.experiments.experiment:runtime              0.26866
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.154434 seconds
# INFO:braindecode.experiments.experiment:Epoch 10
# INFO:braindecode.experiments.experiment:train_loss           3.25371
# INFO:braindecode.experiments.experiment:valid_loss           3.12870
# INFO:braindecode.experiments.experiment:test_loss            2.27938
# INFO:braindecode.experiments.experiment:train_misclass       0.73593
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.70833
# INFO:braindecode.experiments.experiment:runtime              0.26990
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.154260 seconds
# INFO:braindecode.experiments.experiment:Epoch 11
# INFO:braindecode.experiments.experiment:train_loss           2.63149
# INFO:braindecode.experiments.experiment:valid_loss           2.54413
# INFO:braindecode.experiments.experiment:test_loss            1.81165
# INFO:braindecode.experiments.experiment:train_misclass       0.72727
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.66319
# INFO:braindecode.experiments.experiment:runtime              0.26968
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.154263 seconds
# INFO:braindecode.experiments.experiment:Epoch 12
# INFO:braindecode.experiments.experiment:train_loss           2.66728
# INFO:braindecode.experiments.experiment:valid_loss           2.64274
# INFO:braindecode.experiments.experiment:test_loss            1.84773
# INFO:braindecode.experiments.experiment:train_misclass       0.72294
# INFO:braindecode.experiments.experiment:valid_misclass       0.80702
# INFO:braindecode.experiments.experiment:test_misclass        0.65625
# INFO:braindecode.experiments.experiment:runtime              0.26984
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.153744 seconds
# INFO:braindecode.experiments.experiment:Epoch 13
# INFO:braindecode.experiments.experiment:train_loss           2.27661
# INFO:braindecode.experiments.experiment:valid_loss           2.31887
# INFO:braindecode.experiments.experiment:test_loss            1.60056
# INFO:braindecode.experiments.experiment:train_misclass       0.64502
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.59028
# INFO:braindecode.experiments.experiment:runtime              0.26917
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.153714 seconds
# INFO:braindecode.experiments.experiment:Epoch 14
# INFO:braindecode.experiments.experiment:train_loss           1.86123
# INFO:braindecode.experiments.experiment:valid_loss           1.94618
# INFO:braindecode.experiments.experiment:test_loss            1.35910
# INFO:braindecode.experiments.experiment:train_misclass       0.58009
# INFO:braindecode.experiments.experiment:valid_misclass       0.70175
# INFO:braindecode.experiments.experiment:test_misclass        0.55556
# INFO:braindecode.experiments.experiment:runtime              0.26908
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.153743 seconds
# INFO:braindecode.experiments.experiment:Epoch 15
# INFO:braindecode.experiments.experiment:train_loss           2.06416
# INFO:braindecode.experiments.experiment:valid_loss           2.15011
# INFO:braindecode.experiments.experiment:test_loss            1.43008
# INFO:braindecode.experiments.experiment:train_misclass       0.63203
# INFO:braindecode.experiments.experiment:valid_misclass       0.75439
# INFO:braindecode.experiments.experiment:test_misclass        0.55208
# INFO:braindecode.experiments.experiment:runtime              0.26919
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.154322 seconds
# INFO:braindecode.experiments.experiment:Epoch 16
# INFO:braindecode.experiments.experiment:train_loss           1.97772
# INFO:braindecode.experiments.experiment:valid_loss           2.09114
# INFO:braindecode.experiments.experiment:test_loss            1.39180
# INFO:braindecode.experiments.experiment:train_misclass       0.67965
# INFO:braindecode.experiments.experiment:valid_misclass       0.71930
# INFO:braindecode.experiments.experiment:test_misclass        0.59028
# INFO:braindecode.experiments.experiment:runtime              0.26972
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.153831 seconds
# INFO:braindecode.experiments.experiment:Epoch 17
# INFO:braindecode.experiments.experiment:train_loss           1.80424
# INFO:braindecode.experiments.experiment:valid_loss           1.92752
# INFO:braindecode.experiments.experiment:test_loss            1.28142
# INFO:braindecode.experiments.experiment:train_misclass       0.59740
# INFO:braindecode.experiments.experiment:valid_misclass       0.73684
# INFO:braindecode.experiments.experiment:test_misclass        0.50347
# INFO:braindecode.experiments.experiment:runtime              0.26931
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.153963 seconds
# INFO:braindecode.experiments.experiment:Epoch 18
# INFO:braindecode.experiments.experiment:train_loss           1.76934
# INFO:braindecode.experiments.experiment:valid_loss           1.92028
# INFO:braindecode.experiments.experiment:test_loss            1.23905
# INFO:braindecode.experiments.experiment:train_misclass       0.53680
# INFO:braindecode.experiments.experiment:valid_misclass       0.66667
# INFO:braindecode.experiments.experiment:test_misclass        0.45139
# INFO:braindecode.experiments.experiment:runtime              0.26924
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.666667
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.153925 seconds
# INFO:braindecode.experiments.experiment:Epoch 19
# INFO:braindecode.experiments.experiment:train_loss           1.68252
# INFO:braindecode.experiments.experiment:valid_loss           1.83543
# INFO:braindecode.experiments.experiment:test_loss            1.18277
# INFO:braindecode.experiments.experiment:train_misclass       0.52381
# INFO:braindecode.experiments.experiment:valid_misclass       0.64912
# INFO:braindecode.experiments.experiment:test_misclass        0.43750
# INFO:braindecode.experiments.experiment:runtime              0.26994
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.649123
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.153296 seconds
# INFO:braindecode.experiments.experiment:Epoch 20
# INFO:braindecode.experiments.experiment:train_loss           1.86595
# INFO:braindecode.experiments.experiment:valid_loss           2.01979
# INFO:braindecode.experiments.experiment:test_loss            1.24411
# INFO:braindecode.experiments.experiment:train_misclass       0.59307
# INFO:braindecode.experiments.experiment:valid_misclass       0.70175
# INFO:braindecode.experiments.experiment:test_misclass        0.46528
# INFO:braindecode.experiments.experiment:runtime              0.26916
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Setup for second stop...
# INFO:braindecode.experiments.experiment:Train loss to reach 1.68252
# INFO:braindecode.experiments.experiment:Run until second stop...
# INFO:braindecode.experiments.experiment:Epoch 20
# INFO:braindecode.experiments.experiment:train_loss           1.86858
# INFO:braindecode.experiments.experiment:valid_loss           2.19833
# INFO:braindecode.experiments.experiment:test_loss            1.25461
# INFO:braindecode.experiments.experiment:train_misclass       0.55903
# INFO:braindecode.experiments.experiment:valid_misclass       0.64912
# INFO:braindecode.experiments.experiment:test_misclass        0.47917
# INFO:braindecode.experiments.experiment:runtime              0.16682
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.196003 seconds
# INFO:braindecode.experiments.experiment:Epoch 21
# INFO:braindecode.experiments.experiment:train_loss           2.21104
# INFO:braindecode.experiments.experiment:valid_loss           2.58494
# INFO:braindecode.experiments.experiment:test_loss            1.39033
# INFO:braindecode.experiments.experiment:train_misclass       0.60764
# INFO:braindecode.experiments.experiment:valid_misclass       0.68421
# INFO:braindecode.experiments.experiment:test_misclass        0.49653
# INFO:braindecode.experiments.experiment:runtime              0.32260
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.194584 seconds
# INFO:braindecode.experiments.experiment:Epoch 22
# INFO:braindecode.experiments.experiment:train_loss           1.39353
# INFO:braindecode.experiments.experiment:valid_loss           1.74729
# INFO:braindecode.experiments.experiment:test_loss            1.01712
# INFO:braindecode.experiments.experiment:train_misclass       0.47917
# INFO:braindecode.experiments.experiment:valid_misclass       0.59649
# INFO:braindecode.experiments.experiment:test_misclass        0.39236
# INFO:braindecode.experiments.experiment:runtime              0.32122
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.195732 seconds
# INFO:braindecode.experiments.experiment:Epoch 23
# INFO:braindecode.experiments.experiment:train_loss           1.58978
# INFO:braindecode.experiments.experiment:valid_loss           1.97907
# INFO:braindecode.experiments.experiment:test_loss            1.06800
# INFO:braindecode.experiments.experiment:train_misclass       0.46875
# INFO:braindecode.experiments.experiment:valid_misclass       0.57895
# INFO:braindecode.experiments.experiment:test_misclass        0.37153
# INFO:braindecode.experiments.experiment:runtime              0.32232
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.195755 seconds
# INFO:braindecode.experiments.experiment:Epoch 24
# INFO:braindecode.experiments.experiment:train_loss           1.24184
# INFO:braindecode.experiments.experiment:valid_loss           1.61348
# INFO:braindecode.experiments.experiment:test_loss            0.94027
# INFO:braindecode.experiments.experiment:train_misclass       0.42361
# INFO:braindecode.experiments.experiment:valid_misclass       0.52632
# INFO:braindecode.experiments.experiment:test_misclass        0.36458
# INFO:braindecode.experiments.experiment:runtime              0.32255
# INFO:braindecode.experiments.experiment:

# %% [markdown]
# As you can see from the output, there are two phases.
#
# 1. The experiment first runs until the stop criterion is fulfilled (this stop criterion should normally use the performance on the validation set).
# 2. Then it takes the parameters from the model with the lowest validation misclass. It merges the validation set into the training set and runs until the loss on the validation set is below the loss on the training set at the epoch of the best model. Also it will stop if it has run as many epochs in the second phase as it needed until the lowest validation misclass). This is all hardcoded atm as I am quite happy with this setup :)
#
# In our case, epoch 19 had the lowest validation misclass. In epoch 19, the train loss was 1.91. So it had to reach a validation loss below 1.91 in the second phase, which it did in epoch 23.

# %% [markdown]
# ## Experiment with windows cut out of trials

# %% [markdown]
# We will now use an experiment with windows cut out of trials. First we show the things that remain the same as in the last experiment (except we already change the shape of the input to match our smaller windows).

# %%
lasagne.random.set_rng(RandomState(9859295))
in_shape = list(dataset.get_topological_view().shape)
in_shape[0] = None # to allow arbitrary sizes of batches
in_shape[2] = 300 # we will use windows with 300 samples
in_layer = InputLayer(shape=in_shape)
network = DimshuffleLayer(incoming= in_layer, pattern=[0, 3, 2, 1])
network = Conv2DLayer(incoming=network, num_filters=40,
    filter_size=[15, 1], nonlinearity=lasagne.nonlinearities.identity, name='time_conv')
network = DropoutLayer(incoming=network, p=0.5)
network = Conv2DAllColsLayer(incoming=network, num_filters=40,
    filter_size=[1, -1], nonlinearity=theano.tensor.sqr, name='spat_conv')
network = SumPool2dLayer(incoming=network, pool_size=[50, 1],
    stride=[10, 1], mode='average_exc_pad')
network = NonlinearityLayer(incoming=network, 
    nonlinearity=theano.tensor.log)
network = DropoutLayer(incoming=network, p=0.5)
network = DenseLayer(incoming=network,
    num_units=4, nonlinearity=lasagne.nonlinearities.softmax, name='final_dense')

dataset_splitter=FixedTrialSplitter(n_train_trials=288, valid_set_fraction=0.2)
preprocessor = OnlineAxiswiseStandardize(axis=['c', 1])
updates_var_func=lasagne.updates.adam
loss_var_func= lasagne.objectives.categorical_crossentropy
updates_modifier = MaxNormConstraint({
            'time_conv': 2.0,
            'spat_conv': 2.0,
            'final_dense': 0.5})

# %% [markdown]
# We use a different iterator which will always cut windows out of the trials. We use windows of 300 samples and a stride of 30 samples between the windows
# Also we need to use a different monitor which will take the average over all windows of a trial to compute
# the prediction for that trial. This assures we can make a fair comparison between both training ways.
# To make our early stopping sensible, we also now stop once the valid misclass has not improved for 2 epochs (normally we would use 20 epochs in this example).

# %%
from braindecode.datahandling.batch_iteration import WindowsIterator
from braindecode.veganlasagne.stopping import Or, NoDecrease
from braindecode.veganlasagne.monitors import WindowMisclassMonitor

dataset_iterator = WindowsIterator(n_samples_per_window=300,batch_size=60,
                                   sample_axes_name=0, n_sample_stride=30)

stop_criterion = NoDecrease('valid_misclass', num_epochs=2)

monitors=[LossMonitor(), WindowMisclassMonitor(), RuntimeMonitor()]

# %%
exp = Experiment(network, dataset, dataset_splitter, preprocessor,
          dataset_iterator, loss_var_func, updates_var_func, updates_modifier, monitors, stop_criterion)
exp.setup()
exp.run()
# Out:
# INFO:braindecode.experiments.experiment:Layers...
# INFO:braindecode.experiments.experiment:InputLayer
# INFO:braindecode.experiments.experiment:[None, 22, 300, 1]
# INFO:braindecode.experiments.experiment:DimshuffleLayer
# INFO:braindecode.experiments.experiment:(None, 1, 300, 22)
# INFO:braindecode.experiments.experiment:Conv2DLayer
# INFO:braindecode.experiments.experiment:(None, 40, 286, 22)
# INFO:braindecode.experiments.experiment:DropoutLayer
# INFO:braindecode.experiments.experiment:(None, 40, 286, 22)
# INFO:braindecode.experiments.experiment:Conv2DAllColsLayer
# INFO:braindecode.experiments.experiment:(None, 40, 286, 1)
# INFO:braindecode.experiments.experiment:SumPool2dLayer
# INFO:braindecode.experiments.experiment:(None, 40, 24, 1)
# INFO:braindecode.experiments.experiment:NonlinearityLayer
# INFO:braindecode.experiments.experiment:(None, 40, 24, 1)
# INFO:braindecode.experiments.experiment:DropoutLayer
# INFO:braindecode.experiments.experiment:(None, 40, 24, 1)
# INFO:braindecode.experiments.experiment:DenseLayer
# INFO:braindecode.experiments.experiment:(None, 4)
# INFO:braindecode.experiments.experiment:Create theano functions...
# INFO:braindecode.veganlasagne.update_modifiers:Constraining time_conv to norm 2.00
# INFO:braindecode.veganlasagne.update_modifiers:Constraining spat_conv to norm 2.00
# INFO:braindecode.veganlasagne.update_modifiers:Constraining final_dense to norm 0.50
# INFO:braindecode.experiments.experiment:Done.
# INFO:braindecode.experiments.experiment:Run until first stop...
# INFO:braindecode.experiments.experiment:Split/Preprocess datasets...
# INFO:braindecode.experiments.experiment:...Done
# INFO:braindecode.experiments.experiment:Epoch 0
# INFO:braindecode.experiments.experiment:train_loss           1.75197
# INFO:braindecode.experiments.experiment:valid_loss           1.95171
# INFO:braindecode.experiments.experiment:test_loss            2.06731
# INFO:braindecode.experiments.experiment:train_misclass       0.76190
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.75347
# INFO:braindecode.experiments.experiment:runtime              0.00000
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.771930
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.981599 seconds
# INFO:braindecode.experiments.experiment:Epoch 1
# INFO:braindecode.experiments.experiment:train_loss           2.16340
# INFO:braindecode.experiments.experiment:valid_loss           1.92337
# INFO:braindecode.experiments.experiment:test_loss            1.62459
# INFO:braindecode.experiments.experiment:train_misclass       0.74459
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.68403
# INFO:braindecode.experiments.experiment:runtime              1.81888
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.771930
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.982956 seconds
# INFO:braindecode.experiments.experiment:Epoch 2
# INFO:braindecode.experiments.experiment:train_loss           1.57384
# INFO:braindecode.experiments.experiment:valid_loss           1.53659
# INFO:braindecode.experiments.experiment:test_loss            1.23549
# INFO:braindecode.experiments.experiment:train_misclass       0.52814
# INFO:braindecode.experiments.experiment:valid_misclass       0.59649
# INFO:braindecode.experiments.experiment:test_misclass        0.43056
# INFO:braindecode.experiments.experiment:runtime              1.73252
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.596491
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.983123 seconds
# INFO:braindecode.experiments.experiment:Epoch 3
# INFO:braindecode.experiments.experiment:train_loss           1.18400
# INFO:braindecode.experiments.experiment:valid_loss           1.27799
# INFO:braindecode.experiments.experiment:test_loss            1.07791
# INFO:braindecode.experiments.experiment:train_misclass       0.44589
# INFO:braindecode.experiments.experiment:valid_misclass       0.47368
# INFO:braindecode.experiments.experiment:test_misclass        0.41667
# INFO:braindecode.experiments.experiment:runtime              1.73314
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.473684
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.981585 seconds
# INFO:braindecode.experiments.experiment:Epoch 4
# INFO:braindecode.experiments.experiment:train_loss           0.93185
# INFO:braindecode.experiments.experiment:valid_loss           1.24147
# INFO:braindecode.experiments.experiment:test_loss            1.14909
# INFO:braindecode.experiments.experiment:train_misclass       0.32900
# INFO:braindecode.experiments.experiment:valid_misclass       0.49123
# INFO:braindecode.experiments.experiment:test_misclass        0.40972
# INFO:braindecode.experiments.experiment:runtime              1.73189
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.982627 seconds
# INFO:braindecode.experiments.experiment:Epoch 5
# INFO:braindecode.experiments.experiment:train_loss           0.85270
# INFO:braindecode.experiments.experiment:valid_loss           1.15186
# INFO:braindecode.experiments.experiment:test_loss            0.88813
# INFO:braindecode.experiments.experiment:train_misclass       0.31602
# INFO:braindecode.experiments.experiment:valid_misclass       0.45614
# INFO:braindecode.experiments.experiment:test_misclass        0.32639
# INFO:braindecode.experiments.experiment:runtime              1.73132
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.456140
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.981412 seconds
# INFO:braindecode.experiments.experiment:Epoch 6
# INFO:braindecode.experiments.experiment:train_loss           0.86189
# INFO:braindecode.experiments.experiment:valid_loss           1.17621
# INFO:braindecode.experiments.experiment:test_loss            0.92825
# INFO:braindecode.experiments.experiment:train_misclass       0.29437
# INFO:braindecode.experiments.experiment:valid_misclass       0.40351
# INFO:braindecode.experiments.experiment:test_misclass        0.32639
# INFO:braindecode.experiments.experiment:runtime              1.73160
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.403509
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.981552 seconds
# INFO:braindecode.experiments.experiment:Epoch 7
# INFO:braindecode.experiments.experiment:train_loss           0.89844
# INFO:braindecode.experiments.experiment:valid_loss           1.19544
# INFO:braindecode.experiments.experiment:test_loss            0.87617
# INFO:braindecode.experiments.experiment:train_misclass       0.30736
# INFO:braindecode.experiments.experiment:valid_misclass       0.38596
# INFO:braindecode.experiments.experiment:test_misclass        0.29514
# INFO:braindecode.experiments.experiment:runtime              1.73121
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.385965
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.982638 seconds
# INFO:braindecode.experiments.experiment:Epoch 8
# INFO:braindecode.experiments.experiment:train_loss           0.55341
# INFO:braindecode.experiments.experiment:valid_loss           1.02139
# INFO:braindecode.experiments.experiment:test_loss            0.96982
# INFO:braindecode.experiments.experiment:train_misclass       0.18182
# INFO:braindecode.experiments.experiment:valid_misclass       0.35088
# INFO:braindecode.experiments.experiment:test_misclass        0.33333
# INFO:braindecode.experiments.experiment:runtime              1.73166
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.350877
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.983053 seconds
# INFO:braindecode.experiments.experiment:Epoch 9
# INFO:braindecode.experiments.experiment:train_loss           0.54263
# INFO:braindecode.experiments.experiment:valid_loss           0.97264
# INFO:braindecode.experiments.experiment:test_loss            1.13702
# INFO:braindecode.experiments.experiment:train_misclass       0.18182
# INFO:braindecode.experiments.experiment:valid_misclass       0.31579
# INFO:braindecode.experiments.experiment:test_misclass        0.34375
# INFO:braindecode.experiments.experiment:runtime              1.73336
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.315789
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.982697 seconds
# INFO:braindecode.experiments.experiment:Epoch 10
# INFO:braindecode.experiments.experiment:train_loss           0.50395
# INFO:braindecode.experiments.experiment:valid_loss           0.96790
# INFO:braindecode.experiments.experiment:test_loss            0.85056
# INFO:braindecode.experiments.experiment:train_misclass       0.16883
# INFO:braindecode.experiments.experiment:valid_misclass       0.28070
# INFO:braindecode.experiments.experiment:test_misclass        0.28472
# INFO:braindecode.experiments.experiment:runtime              1.73192
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.280702
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.983191 seconds
# INFO:braindecode.experiments.experiment:Epoch 11
# INFO:braindecode.experiments.experiment:train_loss           0.66490
# INFO:braindecode.experiments.experiment:valid_loss           1.03821
# INFO:braindecode.experiments.experiment:test_loss            1.03306
# INFO:braindecode.experiments.experiment:train_misclass       0.21645
# INFO:braindecode.experiments.experiment:valid_misclass       0.31579
# INFO:braindecode.experiments.experiment:test_misclass        0.34722
# INFO:braindecode.experiments.experiment:runtime              1.73378
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.981937 seconds
# INFO:braindecode.experiments.experiment:Epoch 12
# INFO:braindecode.experiments.experiment:train_loss           0.67976
# INFO:braindecode.experiments.experiment:valid_loss           1.05177
# INFO:braindecode.experiments.experiment:test_loss            0.65928
# INFO:braindecode.experiments.experiment:train_misclass       0.24242
# INFO:braindecode.experiments.experiment:valid_misclass       0.26316
# INFO:braindecode.experiments.experiment:test_misclass        0.19792
# INFO:braindecode.experiments.experiment:runtime              1.73098
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.263158
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.982832 seconds
# INFO:braindecode.experiments.experiment:Epoch 13
# INFO:braindecode.experiments.experiment:train_loss           0.39073
# INFO:braindecode.experiments.experiment:valid_loss           1.01070
# INFO:braindecode.experiments.experiment:test_loss            0.81749
# INFO:braindecode.experiments.experiment:train_misclass       0.11255
# INFO:braindecode.experiments.experiment:valid_misclass       0.21053
# INFO:braindecode.experiments.experiment:test_misclass        0.25000
# INFO:braindecode.experiments.experiment:runtime              1.73179
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.210526
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.982577 seconds
# INFO:braindecode.experiments.experiment:Epoch 14
# INFO:braindecode.experiments.experiment:train_loss           0.42667
# INFO:braindecode.experiments.experiment:valid_loss           0.92112
# INFO:braindecode.experiments.experiment:test_loss            0.72979
# INFO:braindecode.experiments.experiment:train_misclass       0.12554
# INFO:braindecode.experiments.experiment:valid_misclass       0.26316
# INFO:braindecode.experiments.experiment:test_misclass        0.23264
# INFO:braindecode.experiments.experiment:runtime              1.73168
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.980677 seconds
# INFO:braindecode.experiments.experiment:Epoch 15
# INFO:braindecode.experiments.experiment:train_loss           0.42835
# INFO:braindecode.experiments.experiment:valid_loss           0.96322
# INFO:braindecode.experiments.experiment:test_loss            0.68313
# INFO:braindecode.experiments.experiment:train_misclass       0.13420
# INFO:braindecode.experiments.experiment:valid_misclass       0.26316
# INFO:braindecode.experiments.experiment:test_misclass        0.21181
# INFO:braindecode.experiments.experiment:runtime              1.72918
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Setup for second stop...
# INFO:braindecode.experiments.experiment:Train loss to reach 0.39073
# INFO:braindecode.experiments.experiment:Run until second stop...
# INFO:braindecode.experiments.experiment:Epoch 14
# INFO:braindecode.experiments.experiment:train_loss           0.52253
# INFO:braindecode.experiments.experiment:valid_loss           0.98982
# INFO:braindecode.experiments.experiment:test_loss            0.71848
# INFO:braindecode.experiments.experiment:train_misclass       0.14236
# INFO:braindecode.experiments.experiment:valid_misclass       0.26316
# INFO:braindecode.experiments.experiment:test_misclass        0.22569
# INFO:braindecode.experiments.experiment:runtime              0.80141
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.218920 seconds
# INFO:braindecode.experiments.experiment:Epoch 15
# INFO:braindecode.experiments.experiment:train_loss           0.47918
# INFO:braindecode.experiments.experiment:valid_loss           0.74319
# INFO:braindecode.experiments.experiment:test_loss            0.74595
# INFO:braindecode.experiments.experiment:train_misclass       0.14931
# INFO:braindecode.experiments.experiment:valid_misclass       0.26316
# INFO:braindecode.experiments.experiment:test_misclass        0.25347
# INFO:braindecode.experiments.experiment:runtime              2.04143
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.218541 seconds
# INFO:braindecode.experiments.experiment:Epoch 16
# INFO:braindecode.experiments.experiment:train_loss           0.37884
# INFO:braindecode.experiments.experiment:valid_loss           0.63771
# INFO:braindecode.experiments.experiment:test_loss            0.71610
# INFO:braindecode.experiments.experiment:train_misclass       0.07639
# INFO:braindecode.experiments.experiment:valid_misclass       0.17544
# INFO:braindecode.experiments.experiment:test_misclass        0.23264
# INFO:braindecode.experiments.experiment:runtime              2.04132
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.218109 seconds
# INFO:braindecode.experiments.experiment:Epoch 17
# INFO:braindecode.experiments.experiment:train_loss           0.43341
# INFO:braindecode.experiments.experiment:valid_loss           0.68884
# INFO:braindecode.experiments.experiment:test_loss            0.66960
# INFO:braindecode.experiments.experiment:train_misclass       0.11111
# INFO:braindecode.experiments.experiment:valid_misclass       0.19298
# INFO:braindecode.experiments.experiment:test_misclass        0.21528
# INFO:braindecode.experiments.experiment:runtime              2.04063
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.217502 seconds
# INFO:braindecode.experiments.experiment:Epoch 18
# INFO:braindecode.experiments.experiment:train_loss           0.50985
# INFO:braindecode.experiments.experiment:valid_loss           0.71576
# INFO:braindecode.experiments.experiment:test_loss            0.81538
# INFO:braindecode.experiments.experiment:train_misclass       0.14931
# INFO:braindecode.experiments.experiment:valid_misclass       0.22807
# INFO:braindecode.experiments.experiment:test_misclass        0.25000
# INFO:braindecode.experiments.experiment:runtime              2.04044
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.218091 seconds
# INFO:braindecode.experiments.experiment:Epoch 19
# INFO:braindecode.experiments.experiment:train_loss           0.50806
# INFO:braindecode.experiments.experiment:valid_loss           0.71971
# INFO:braindecode.experiments.experiment:test_loss            0.65547
# INFO:braindecode.experiments.experiment:train_misclass       0.15625
# INFO:braindecode.experiments.experiment:valid_misclass       0.22807
# INFO:braindecode.experiments.experiment:test_misclass        0.21181
# INFO:braindecode.experiments.experiment:runtime              2.04133
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.219517 seconds
# INFO:braindecode.experiments.experiment:Epoch 20
# INFO:braindecode.experiments.experiment:train_loss           0.51407
# INFO:braindecode.experiments.experiment:valid_loss           0.70843
# INFO:braindecode.experiments.experiment:test_loss            0.67737
# INFO:braindecode.experiments.experiment:train_misclass       0.17014
# INFO:braindecode.experiments.experiment:valid_misclass       0.22807
# INFO:braindecode.experiments.experiment:test_misclass        0.21181
# INFO:braindecode.experiments.experiment:runtime              2.04266
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.218444 seconds
# INFO:braindecode.experiments.experiment:Epoch 21
# INFO:braindecode.experiments.experiment:train_loss           0.54367
# INFO:braindecode.experiments.experiment:valid_loss           0.75332
# INFO:braindecode.experiments.experiment:test_loss            0.62609
# INFO:braindecode.experiments.experiment:train_misclass       0.18056
# INFO:braindecode.experiments.experiment:valid_misclass       0.22807
# INFO:braindecode.experiments.experiment:test_misclass        0.18750
# INFO:braindecode.experiments.experiment:runtime              2.04081
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.218440 seconds
# INFO:braindecode.experiments.experiment:Epoch 22
# INFO:braindecode.experiments.experiment:train_loss           0.39359
# INFO:braindecode.experiments.experiment:valid_loss           0.59580
# INFO:braindecode.experiments.experiment:test_loss            0.59392
# INFO:braindecode.experiments.experiment:train_misclass       0.07986
# INFO:braindecode.experiments.experiment:valid_misclass       0.14035
# INFO:braindecode.experiments.experiment:test_misclass        0.19097
# INFO:braindecode.experiments.experiment:runtime              2.04107
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.218781 seconds
# INFO:braindecode.experiments.experiment:Epoch 23
# INFO:braindecode.experiments.experiment:train_loss           0.42568
# INFO:braindecode.experiments.experiment:valid_loss           0.58354
# INFO:braindecode.experiments.experiment:test_loss            0.68409
# INFO:braindecode.experiments.experiment:train_misclass       0.11806
# INFO:braindecode.experiments.experiment:valid_misclass       0.21053
# INFO:braindecode.experiments.experiment:test_misclass        0.22569
# INFO:braindecode.experiments.experiment:runtime              2.04252
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.217638 seconds
# INFO:braindecode.experiments.experiment:Epoch 24
# INFO:braindecode.experiments.experiment:train_loss           0.42998
# INFO:braindecode.experiments.experiment:valid_loss           0.65582
# INFO:braindecode.experiments.experiment:test_loss            0.59714
# INFO:braindecode.experiments.experiment:train_misclass       0.11458
# INFO:braindecode.experiments.experiment:valid_misclass       0.17544
# INFO:braindecode.experiments.experiment:test_misclass        0.18403
# INFO:braindecode.experiments.experiment:runtime              2.04084
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.217619 seconds
# INFO:braindecode.experiments.experiment:Epoch 25
# INFO:braindecode.experiments.experiment:train_loss           0.38976
# INFO:braindecode.experiments.experiment:valid_loss           0.57766
# INFO:braindecode.experiments.experiment:test_loss            0.58042
# INFO:braindecode.experiments.experiment:train_misclass       0.09375
# INFO:braindecode.experiments.experiment:valid_misclass       0.15789
# INFO:braindecode.experiments.experiment:test_misclass        0.16319
# INFO:braindecode.experiments.experiment:runtime              2.04063
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.218494 seconds
# INFO:braindecode.experiments.experiment:Epoch 26
# INFO:braindecode.experiments.experiment:train_loss           0.35229
# INFO:braindecode.experiments.experiment:valid_loss           0.53379
# INFO:braindecode.experiments.experiment:test_loss            0.62649
# INFO:braindecode.experiments.experiment:train_misclass       0.07639
# INFO:braindecode.experiments.experiment:valid_misclass       0.15789
# INFO:braindecode.experiments.experiment:test_misclass        0.20139
# INFO:braindecode.experiments.experiment:runtime              2.04121
# INFO:braindecode.experiments.experiment:

# %% [markdown]
# The epochs are now much slower, which is because there are much more windows than there were trials before (about 10 times more with our parameters).

# %% [markdown]
# ## Experiment with model making predictions for every window

# %% [markdown]
# One disadvantage of the way to use windows out of the trials like that is net does a lot of computations multiple times. Think of the first convolutional layer over time, when being applied to two neighbouring windows, it will do the same computations multiple times.
#
# A different way to make multiple predictions for one trial is to put it into the model explicitly. If we replace the final dense layer by a convolution over time + average  over all convolution regions, every  convolution region has to have a sensible prediction.
#
# I have never done this before, so let's try it :)
# Note the final 3 layers of the network have changed. A filter size of 22 means we are using 22 pooling regions which is again about half of the trial (ignoring border effects).

# %%
from lasagne.layers import GlobalPoolLayer
import theano.tensor as T
lasagne.random.set_rng(RandomState(9859295))
in_shape = list(dataset.get_topological_view().shape)
in_shape[0] = None # to allow arbitrary sizes of batches
in_layer = InputLayer(shape=in_shape)
network = DimshuffleLayer(incoming= in_layer, pattern=[0, 3, 2, 1])
network = Conv2DLayer(incoming=network, num_filters=40,
    filter_size=[15, 1], nonlinearity=lasagne.nonlinearities.identity, name='time_conv')
network = DropoutLayer(incoming=network, p=0.5)
network = Conv2DAllColsLayer(incoming=network, num_filters=40,
    filter_size=[1, -1], nonlinearity=theano.tensor.sqr, name='spat_conv')
network = SumPool2dLayer(incoming=network, pool_size=[50, 1],
    stride=[10, 1], mode='average_exc_pad')
network = NonlinearityLayer(incoming=network, 
    nonlinearity=theano.tensor.log)
network = DropoutLayer(incoming=network, p=0.5)
network = Conv2DLayer(incoming=network,
    num_filters=4, filter_size=[22, 1], nonlinearity=lasagne.nonlinearities.identity, name='final_conv')
network = GlobalPoolLayer(incoming=network, pool_function=T.mean)
network = NonlinearityLayer(incoming=network, nonlinearity=lasagne.nonlinearities.softmax) 



dataset_splitter=FixedTrialSplitter(n_train_trials=288, valid_set_fraction=0.2)
preprocessor = OnlineAxiswiseStandardize(axis=['c', 1])
updates_var_func=lasagne.updates.adam
loss_var_func= lasagne.objectives.categorical_crossentropy
updates_modifier = MaxNormConstraint({
            'time_conv': 2.0,
            'spat_conv': 2.0,
            'final_conv': 2.0})
dataset_iterator = BalancedBatchIterator(batch_size=60)

stop_criterion = NoDecrease('valid_misclass', num_epochs=2)

monitors=[LossMonitor(), MisclassMonitor(), RuntimeMonitor()]
exp = Experiment(network, dataset, dataset_splitter, preprocessor,
          dataset_iterator, loss_var_func, updates_var_func, updates_modifier, monitors, stop_criterion)
exp.setup()
exp.run()
# Out:
# INFO:braindecode.experiments.experiment:Layers...
# INFO:braindecode.experiments.experiment:InputLayer
# INFO:braindecode.experiments.experiment:[None, 22, 600, 1]
# INFO:braindecode.experiments.experiment:DimshuffleLayer
# INFO:braindecode.experiments.experiment:(None, 1, 600, 22)
# INFO:braindecode.experiments.experiment:Conv2DLayer
# INFO:braindecode.experiments.experiment:(None, 40, 586, 22)
# INFO:braindecode.experiments.experiment:DropoutLayer
# INFO:braindecode.experiments.experiment:(None, 40, 586, 22)
# INFO:braindecode.experiments.experiment:Conv2DAllColsLayer
# INFO:braindecode.experiments.experiment:(None, 40, 586, 1)
# INFO:braindecode.experiments.experiment:SumPool2dLayer
# INFO:braindecode.experiments.experiment:(None, 40, 54, 1)
# INFO:braindecode.experiments.experiment:NonlinearityLayer
# INFO:braindecode.experiments.experiment:(None, 40, 54, 1)
# INFO:braindecode.experiments.experiment:DropoutLayer
# INFO:braindecode.experiments.experiment:(None, 40, 54, 1)
# INFO:braindecode.experiments.experiment:Conv2DLayer
# INFO:braindecode.experiments.experiment:(None, 4, 33, 1)
# INFO:braindecode.experiments.experiment:GlobalPoolLayer
# INFO:braindecode.experiments.experiment:(None, 4)
# INFO:braindecode.experiments.experiment:NonlinearityLayer
# INFO:braindecode.experiments.experiment:(None, 4)
# INFO:braindecode.experiments.experiment:Create theano functions...
# INFO:braindecode.veganlasagne.update_modifiers:Constraining time_conv to norm 2.00
# INFO:braindecode.veganlasagne.update_modifiers:Constraining spat_conv to norm 2.00
# INFO:braindecode.veganlasagne.update_modifiers:Constraining final_conv to norm 2.00
# INFO:braindecode.experiments.experiment:Done.
# INFO:braindecode.experiments.experiment:Run until first stop...
# INFO:braindecode.experiments.experiment:Split/Preprocess datasets...
# INFO:braindecode.experiments.experiment:...Done
# INFO:braindecode.experiments.experiment:Epoch 0
# INFO:braindecode.experiments.experiment:train_loss           1.84469
# INFO:braindecode.experiments.experiment:valid_loss           2.11771
# INFO:braindecode.experiments.experiment:test_loss            2.20087
# INFO:braindecode.experiments.experiment:train_misclass       0.74459
# INFO:braindecode.experiments.experiment:valid_misclass       0.73684
# INFO:braindecode.experiments.experiment:test_misclass        0.74306
# INFO:braindecode.experiments.experiment:runtime              0.00000
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.736842
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.168994 seconds
# INFO:braindecode.experiments.experiment:Epoch 1
# INFO:braindecode.experiments.experiment:train_loss           2.69921
# INFO:braindecode.experiments.experiment:valid_loss           2.73141
# INFO:braindecode.experiments.experiment:test_loss            2.86817
# INFO:braindecode.experiments.experiment:train_misclass       0.65368
# INFO:braindecode.experiments.experiment:valid_misclass       0.59649
# INFO:braindecode.experiments.experiment:test_misclass        0.66319
# INFO:braindecode.experiments.experiment:runtime              0.30494
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.596491
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155378 seconds
# INFO:braindecode.experiments.experiment:Epoch 2
# INFO:braindecode.experiments.experiment:train_loss           1.48064
# INFO:braindecode.experiments.experiment:valid_loss           1.50237
# INFO:braindecode.experiments.experiment:test_loss            1.43594
# INFO:braindecode.experiments.experiment:train_misclass       0.73593
# INFO:braindecode.experiments.experiment:valid_misclass       0.73684
# INFO:braindecode.experiments.experiment:test_misclass        0.75000
# INFO:braindecode.experiments.experiment:runtime              0.27675
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155848 seconds
# INFO:braindecode.experiments.experiment:Epoch 3
# INFO:braindecode.experiments.experiment:train_loss           1.56930
# INFO:braindecode.experiments.experiment:valid_loss           1.60584
# INFO:braindecode.experiments.experiment:test_loss            1.50957
# INFO:braindecode.experiments.experiment:train_misclass       0.74892
# INFO:braindecode.experiments.experiment:valid_misclass       0.73684
# INFO:braindecode.experiments.experiment:test_misclass        0.65972
# INFO:braindecode.experiments.experiment:runtime              0.27290
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Setup for second stop...
# INFO:braindecode.experiments.experiment:Train loss to reach 2.69921
# INFO:braindecode.experiments.experiment:Run until second stop...
# INFO:braindecode.experiments.experiment:Epoch 2
# INFO:braindecode.experiments.experiment:train_loss           2.69155
# INFO:braindecode.experiments.experiment:valid_loss           2.69352
# INFO:braindecode.experiments.experiment:test_loss            2.83822
# INFO:braindecode.experiments.experiment:train_misclass       0.65625
# INFO:braindecode.experiments.experiment:valid_misclass       0.61404
# INFO:braindecode.experiments.experiment:test_misclass        0.67014
# INFO:braindecode.experiments.experiment:runtime              0.16944
# INFO:braindecode.experiments.experiment:

# %% [markdown]
# We see the speed is much faster but it doesn't seem to learn so much yet, so let's continue training a little longer.

# %%
exp.stop_criterion = MaxEpochs(num_epochs=50)
exp.run_until_early_stop()
# Out:
# INFO:braindecode.experiments.experiment:Split/Preprocess datasets...
# INFO:braindecode.experiments.experiment:...Done
# INFO:braindecode.experiments.experiment:Epoch 0
# INFO:braindecode.experiments.experiment:train_loss           2.69921
# INFO:braindecode.experiments.experiment:valid_loss           2.73141
# INFO:braindecode.experiments.experiment:test_loss            2.86817
# INFO:braindecode.experiments.experiment:train_misclass       0.65368
# INFO:braindecode.experiments.experiment:valid_misclass       0.59649
# INFO:braindecode.experiments.experiment:test_misclass        0.66319
# INFO:braindecode.experiments.experiment:runtime              0.00000
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.596491
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.156050 seconds
# INFO:braindecode.experiments.experiment:Epoch 1
# INFO:braindecode.experiments.experiment:train_loss           1.42979
# INFO:braindecode.experiments.experiment:valid_loss           1.45552
# INFO:braindecode.experiments.experiment:test_loss            1.41426
# INFO:braindecode.experiments.experiment:train_misclass       0.74892
# INFO:braindecode.experiments.experiment:valid_misclass       0.73684
# INFO:braindecode.experiments.experiment:test_misclass        0.74306
# INFO:braindecode.experiments.experiment:runtime              0.27372
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155204 seconds
# INFO:braindecode.experiments.experiment:Epoch 2
# INFO:braindecode.experiments.experiment:train_loss           1.45480
# INFO:braindecode.experiments.experiment:valid_loss           1.51051
# INFO:braindecode.experiments.experiment:test_loss            1.46878
# INFO:braindecode.experiments.experiment:train_misclass       0.70130
# INFO:braindecode.experiments.experiment:valid_misclass       0.70175
# INFO:braindecode.experiments.experiment:test_misclass        0.70139
# INFO:braindecode.experiments.experiment:runtime              0.27232
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155112 seconds
# INFO:braindecode.experiments.experiment:Epoch 3
# INFO:braindecode.experiments.experiment:train_loss           1.76458
# INFO:braindecode.experiments.experiment:valid_loss           1.81368
# INFO:braindecode.experiments.experiment:test_loss            1.63907
# INFO:braindecode.experiments.experiment:train_misclass       0.72727
# INFO:braindecode.experiments.experiment:valid_misclass       0.73684
# INFO:braindecode.experiments.experiment:test_misclass        0.66667
# INFO:braindecode.experiments.experiment:runtime              0.27253
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155772 seconds
# INFO:braindecode.experiments.experiment:Epoch 4
# INFO:braindecode.experiments.experiment:train_loss           1.56761
# INFO:braindecode.experiments.experiment:valid_loss           1.59442
# INFO:braindecode.experiments.experiment:test_loss            1.46205
# INFO:braindecode.experiments.experiment:train_misclass       0.65801
# INFO:braindecode.experiments.experiment:valid_misclass       0.63158
# INFO:braindecode.experiments.experiment:test_misclass        0.59375
# INFO:braindecode.experiments.experiment:runtime              0.27321
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155809 seconds
# INFO:braindecode.experiments.experiment:Epoch 5
# INFO:braindecode.experiments.experiment:train_loss           1.84081
# INFO:braindecode.experiments.experiment:valid_loss           1.83203
# INFO:braindecode.experiments.experiment:test_loss            1.56959
# INFO:braindecode.experiments.experiment:train_misclass       0.62771
# INFO:braindecode.experiments.experiment:valid_misclass       0.70175
# INFO:braindecode.experiments.experiment:test_misclass        0.70486
# INFO:braindecode.experiments.experiment:runtime              0.27310
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155928 seconds
# INFO:braindecode.experiments.experiment:Epoch 6
# INFO:braindecode.experiments.experiment:train_loss           1.85477
# INFO:braindecode.experiments.experiment:valid_loss           1.82433
# INFO:braindecode.experiments.experiment:test_loss            1.52179
# INFO:braindecode.experiments.experiment:train_misclass       0.65368
# INFO:braindecode.experiments.experiment:valid_misclass       0.63158
# INFO:braindecode.experiments.experiment:test_misclass        0.63542
# INFO:braindecode.experiments.experiment:runtime              0.27320
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155755 seconds
# INFO:braindecode.experiments.experiment:Epoch 7
# INFO:braindecode.experiments.experiment:train_loss           1.62441
# INFO:braindecode.experiments.experiment:valid_loss           1.60604
# INFO:braindecode.experiments.experiment:test_loss            1.37478
# INFO:braindecode.experiments.experiment:train_misclass       0.59307
# INFO:braindecode.experiments.experiment:valid_misclass       0.63158
# INFO:braindecode.experiments.experiment:test_misclass        0.54514
# INFO:braindecode.experiments.experiment:runtime              0.27321
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155124 seconds
# INFO:braindecode.experiments.experiment:Epoch 8
# INFO:braindecode.experiments.experiment:train_loss           1.98244
# INFO:braindecode.experiments.experiment:valid_loss           1.95569
# INFO:braindecode.experiments.experiment:test_loss            1.57441
# INFO:braindecode.experiments.experiment:train_misclass       0.60606
# INFO:braindecode.experiments.experiment:valid_misclass       0.64912
# INFO:braindecode.experiments.experiment:test_misclass        0.54514
# INFO:braindecode.experiments.experiment:runtime              0.27251
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.156534 seconds
# INFO:braindecode.experiments.experiment:Epoch 9
# INFO:braindecode.experiments.experiment:train_loss           2.26526
# INFO:braindecode.experiments.experiment:valid_loss           2.22690
# INFO:braindecode.experiments.experiment:test_loss            1.72163
# INFO:braindecode.experiments.experiment:train_misclass       0.70996
# INFO:braindecode.experiments.experiment:valid_misclass       0.75439
# INFO:braindecode.experiments.experiment:test_misclass        0.68056
# INFO:braindecode.experiments.experiment:runtime              0.27398
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.156347 seconds
# INFO:braindecode.experiments.experiment:Epoch 10
# INFO:braindecode.experiments.experiment:train_loss           1.90835
# INFO:braindecode.experiments.experiment:valid_loss           1.84279
# INFO:braindecode.experiments.experiment:test_loss            1.39928
# INFO:braindecode.experiments.experiment:train_misclass       0.67100
# INFO:braindecode.experiments.experiment:valid_misclass       0.73684
# INFO:braindecode.experiments.experiment:test_misclass        0.60069
# INFO:braindecode.experiments.experiment:runtime              0.27396
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155710 seconds
# INFO:braindecode.experiments.experiment:Epoch 11
# INFO:braindecode.experiments.experiment:train_loss           2.01201
# INFO:braindecode.experiments.experiment:valid_loss           1.95684
# INFO:braindecode.experiments.experiment:test_loss            1.46391
# INFO:braindecode.experiments.experiment:train_misclass       0.62338
# INFO:braindecode.experiments.experiment:valid_misclass       0.64912
# INFO:braindecode.experiments.experiment:test_misclass        0.52778
# INFO:braindecode.experiments.experiment:runtime              0.27301
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155963 seconds
# INFO:braindecode.experiments.experiment:Epoch 12
# INFO:braindecode.experiments.experiment:train_loss           2.30900
# INFO:braindecode.experiments.experiment:valid_loss           2.26059
# INFO:braindecode.experiments.experiment:test_loss            1.65080
# INFO:braindecode.experiments.experiment:train_misclass       0.65368
# INFO:braindecode.experiments.experiment:valid_misclass       0.71930
# INFO:braindecode.experiments.experiment:test_misclass        0.57986
# INFO:braindecode.experiments.experiment:runtime              0.27338
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155668 seconds
# INFO:braindecode.experiments.experiment:Epoch 13
# INFO:braindecode.experiments.experiment:train_loss           2.12397
# INFO:braindecode.experiments.experiment:valid_loss           2.05124
# INFO:braindecode.experiments.experiment:test_loss            1.47442
# INFO:braindecode.experiments.experiment:train_misclass       0.68398
# INFO:braindecode.experiments.experiment:valid_misclass       0.73684
# INFO:braindecode.experiments.experiment:test_misclass        0.60069
# INFO:braindecode.experiments.experiment:runtime              0.27306
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155630 seconds
# INFO:braindecode.experiments.experiment:Epoch 14
# INFO:braindecode.experiments.experiment:train_loss           1.96878
# INFO:braindecode.experiments.experiment:valid_loss           1.95421
# INFO:braindecode.experiments.experiment:test_loss            1.38129
# INFO:braindecode.experiments.experiment:train_misclass       0.55844
# INFO:braindecode.experiments.experiment:valid_misclass       0.66667
# INFO:braindecode.experiments.experiment:test_misclass        0.52083
# INFO:braindecode.experiments.experiment:runtime              0.27296
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155669 seconds
# INFO:braindecode.experiments.experiment:Epoch 15
# INFO:braindecode.experiments.experiment:train_loss           2.07134
# INFO:braindecode.experiments.experiment:valid_loss           2.00552
# INFO:braindecode.experiments.experiment:test_loss            1.41664
# INFO:braindecode.experiments.experiment:train_misclass       0.63203
# INFO:braindecode.experiments.experiment:valid_misclass       0.66667
# INFO:braindecode.experiments.experiment:test_misclass        0.54167
# INFO:braindecode.experiments.experiment:runtime              0.27319
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155308 seconds
# INFO:braindecode.experiments.experiment:Epoch 16
# INFO:braindecode.experiments.experiment:train_loss           2.28042
# INFO:braindecode.experiments.experiment:valid_loss           2.21843
# INFO:braindecode.experiments.experiment:test_loss            1.52761
# INFO:braindecode.experiments.experiment:train_misclass       0.66234
# INFO:braindecode.experiments.experiment:valid_misclass       0.73684
# INFO:braindecode.experiments.experiment:test_misclass        0.59028
# INFO:braindecode.experiments.experiment:runtime              0.27270
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155675 seconds
# INFO:braindecode.experiments.experiment:Epoch 17
# INFO:braindecode.experiments.experiment:train_loss           2.03100
# INFO:braindecode.experiments.experiment:valid_loss           2.05397
# INFO:braindecode.experiments.experiment:test_loss            1.39285
# INFO:braindecode.experiments.experiment:train_misclass       0.54978
# INFO:braindecode.experiments.experiment:valid_misclass       0.66667
# INFO:braindecode.experiments.experiment:test_misclass        0.51736
# INFO:braindecode.experiments.experiment:runtime              0.27316
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.156258 seconds
# INFO:braindecode.experiments.experiment:Epoch 18
# INFO:braindecode.experiments.experiment:train_loss           1.68788
# INFO:braindecode.experiments.experiment:valid_loss           1.66127
# INFO:braindecode.experiments.experiment:test_loss            1.16065
# INFO:braindecode.experiments.experiment:train_misclass       0.54113
# INFO:braindecode.experiments.experiment:valid_misclass       0.59649
# INFO:braindecode.experiments.experiment:test_misclass        0.45139
# INFO:braindecode.experiments.experiment:runtime              0.27355
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.596491
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155305 seconds
# INFO:braindecode.experiments.experiment:Epoch 19
# INFO:braindecode.experiments.experiment:train_loss           2.26353
# INFO:braindecode.experiments.experiment:valid_loss           2.19833
# INFO:braindecode.experiments.experiment:test_loss            1.43445
# INFO:braindecode.experiments.experiment:train_misclass       0.63636
# INFO:braindecode.experiments.experiment:valid_misclass       0.71930
# INFO:braindecode.experiments.experiment:test_misclass        0.54167
# INFO:braindecode.experiments.experiment:runtime              0.27327
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155639 seconds
# INFO:braindecode.experiments.experiment:Epoch 20
# INFO:braindecode.experiments.experiment:train_loss           2.21848
# INFO:braindecode.experiments.experiment:valid_loss           2.18503
# INFO:braindecode.experiments.experiment:test_loss            1.40779
# INFO:braindecode.experiments.experiment:train_misclass       0.57143
# INFO:braindecode.experiments.experiment:valid_misclass       0.61404
# INFO:braindecode.experiments.experiment:test_misclass        0.47917
# INFO:braindecode.experiments.experiment:runtime              0.27298
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155843 seconds
# INFO:braindecode.experiments.experiment:Epoch 21
# INFO:braindecode.experiments.experiment:train_loss           1.83259
# INFO:braindecode.experiments.experiment:valid_loss           1.85391
# INFO:braindecode.experiments.experiment:test_loss            1.20137
# INFO:braindecode.experiments.experiment:train_misclass       0.51948
# INFO:braindecode.experiments.experiment:valid_misclass       0.61404
# INFO:braindecode.experiments.experiment:test_misclass        0.47569
# INFO:braindecode.experiments.experiment:runtime              0.27312
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155898 seconds
# INFO:braindecode.experiments.experiment:Epoch 22
# INFO:braindecode.experiments.experiment:train_loss           1.94709
# INFO:braindecode.experiments.experiment:valid_loss           1.90840
# INFO:braindecode.experiments.experiment:test_loss            1.19342
# INFO:braindecode.experiments.experiment:train_misclass       0.56277
# INFO:braindecode.experiments.experiment:valid_misclass       0.64912
# INFO:braindecode.experiments.experiment:test_misclass        0.45486
# INFO:braindecode.experiments.experiment:runtime              0.27310
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155744 seconds
# INFO:braindecode.experiments.experiment:Epoch 23
# INFO:braindecode.experiments.experiment:train_loss           1.96220
# INFO:braindecode.experiments.experiment:valid_loss           1.95968
# INFO:braindecode.experiments.experiment:test_loss            1.23755
# INFO:braindecode.experiments.experiment:train_misclass       0.54545
# INFO:braindecode.experiments.experiment:valid_misclass       0.61404
# INFO:braindecode.experiments.experiment:test_misclass        0.44444
# INFO:braindecode.experiments.experiment:runtime              0.27299
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155773 seconds
# INFO:braindecode.experiments.experiment:Epoch 24
# INFO:braindecode.experiments.experiment:train_loss           1.66665
# INFO:braindecode.experiments.experiment:valid_loss           1.73180
# INFO:braindecode.experiments.experiment:test_loss            1.15049
# INFO:braindecode.experiments.experiment:train_misclass       0.49351
# INFO:braindecode.experiments.experiment:valid_misclass       0.63158
# INFO:braindecode.experiments.experiment:test_misclass        0.43750
# INFO:braindecode.experiments.experiment:runtime              0.27298
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155764 seconds
# INFO:braindecode.experiments.experiment:Epoch 25
# INFO:braindecode.experiments.experiment:train_loss           1.75689
# INFO:braindecode.experiments.experiment:valid_loss           1.76755
# INFO:braindecode.experiments.experiment:test_loss            1.08242
# INFO:braindecode.experiments.experiment:train_misclass       0.54113
# INFO:braindecode.experiments.experiment:valid_misclass       0.57895
# INFO:braindecode.experiments.experiment:test_misclass        0.41319
# INFO:braindecode.experiments.experiment:runtime              0.27315
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.578947
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155028 seconds
# INFO:braindecode.experiments.experiment:Epoch 26
# INFO:braindecode.experiments.experiment:train_loss           1.77152
# INFO:braindecode.experiments.experiment:valid_loss           1.80739
# INFO:braindecode.experiments.experiment:test_loss            1.12325
# INFO:braindecode.experiments.experiment:train_misclass       0.52381
# INFO:braindecode.experiments.experiment:valid_misclass       0.57895
# INFO:braindecode.experiments.experiment:test_misclass        0.42361
# INFO:braindecode.experiments.experiment:runtime              0.27283
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.578947
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155145 seconds
# INFO:braindecode.experiments.experiment:Epoch 27
# INFO:braindecode.experiments.experiment:train_loss           1.52254
# INFO:braindecode.experiments.experiment:valid_loss           1.63121
# INFO:braindecode.experiments.experiment:test_loss            1.09772
# INFO:braindecode.experiments.experiment:train_misclass       0.46753
# INFO:braindecode.experiments.experiment:valid_misclass       0.61404
# INFO:braindecode.experiments.experiment:test_misclass        0.44792
# INFO:braindecode.experiments.experiment:runtime              0.27295
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155854 seconds
# INFO:braindecode.experiments.experiment:Epoch 28
# INFO:braindecode.experiments.experiment:train_loss           1.60018
# INFO:braindecode.experiments.experiment:valid_loss           1.64193
# INFO:braindecode.experiments.experiment:test_loss            1.01629
# INFO:braindecode.experiments.experiment:train_misclass       0.51082
# INFO:braindecode.experiments.experiment:valid_misclass       0.56140
# INFO:braindecode.experiments.experiment:test_misclass        0.39583
# INFO:braindecode.experiments.experiment:runtime              0.27316
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.561404
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.156017 seconds
# INFO:braindecode.experiments.experiment:Epoch 29
# INFO:braindecode.experiments.experiment:train_loss           1.55393
# INFO:braindecode.experiments.experiment:valid_loss           1.61178
# INFO:braindecode.experiments.experiment:test_loss            1.02295
# INFO:braindecode.experiments.experiment:train_misclass       0.47619
# INFO:braindecode.experiments.experiment:valid_misclass       0.56140
# INFO:braindecode.experiments.experiment:test_misclass        0.40278
# INFO:braindecode.experiments.experiment:runtime              0.27379
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.561404
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155656 seconds
# INFO:braindecode.experiments.experiment:Epoch 30
# INFO:braindecode.experiments.experiment:train_loss           1.47458
# INFO:braindecode.experiments.experiment:valid_loss           1.65025
# INFO:braindecode.experiments.experiment:test_loss            1.10496
# INFO:braindecode.experiments.experiment:train_misclass       0.44156
# INFO:braindecode.experiments.experiment:valid_misclass       0.61404
# INFO:braindecode.experiments.experiment:test_misclass        0.43056
# INFO:braindecode.experiments.experiment:runtime              0.27342
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155896 seconds
# INFO:braindecode.experiments.experiment:Epoch 31
# INFO:braindecode.experiments.experiment:train_loss           1.62995
# INFO:braindecode.experiments.experiment:valid_loss           1.70136
# INFO:braindecode.experiments.experiment:test_loss            1.00770
# INFO:braindecode.experiments.experiment:train_misclass       0.48918
# INFO:braindecode.experiments.experiment:valid_misclass       0.57895
# INFO:braindecode.experiments.experiment:test_misclass        0.38194
# INFO:braindecode.experiments.experiment:runtime              0.27332
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155089 seconds
# INFO:braindecode.experiments.experiment:Epoch 32
# INFO:braindecode.experiments.experiment:train_loss           1.18019
# INFO:braindecode.experiments.experiment:valid_loss           1.33448
# INFO:braindecode.experiments.experiment:test_loss            1.00538
# INFO:braindecode.experiments.experiment:train_misclass       0.38095
# INFO:braindecode.experiments.experiment:valid_misclass       0.52632
# INFO:braindecode.experiments.experiment:test_misclass        0.40278
# INFO:braindecode.experiments.experiment:runtime              0.27229
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.526316
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.156387 seconds
# INFO:braindecode.experiments.experiment:Epoch 33
# INFO:braindecode.experiments.experiment:train_loss           1.54887
# INFO:braindecode.experiments.experiment:valid_loss           1.74064
# INFO:braindecode.experiments.experiment:test_loss            1.08605
# INFO:braindecode.experiments.experiment:train_misclass       0.43723
# INFO:braindecode.experiments.experiment:valid_misclass       0.57895
# INFO:braindecode.experiments.experiment:test_misclass        0.39931
# INFO:braindecode.experiments.experiment:runtime              0.27439
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155648 seconds
# INFO:braindecode.experiments.experiment:Epoch 34
# INFO:braindecode.experiments.experiment:train_loss           1.43034
# INFO:braindecode.experiments.experiment:valid_loss           1.55936
# INFO:braindecode.experiments.experiment:test_loss            0.92850
# INFO:braindecode.experiments.experiment:train_misclass       0.43290
# INFO:braindecode.experiments.experiment:valid_misclass       0.52632
# INFO:braindecode.experiments.experiment:test_misclass        0.34722
# INFO:braindecode.experiments.experiment:runtime              0.27293
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.526316
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.156406 seconds
# INFO:braindecode.experiments.experiment:Epoch 35
# INFO:braindecode.experiments.experiment:train_loss           1.36539
# INFO:braindecode.experiments.experiment:valid_loss           1.52094
# INFO:braindecode.experiments.experiment:test_loss            0.99809
# INFO:braindecode.experiments.experiment:train_misclass       0.41558
# INFO:braindecode.experiments.experiment:valid_misclass       0.56140
# INFO:braindecode.experiments.experiment:test_misclass        0.40278
# INFO:braindecode.experiments.experiment:runtime              0.27427
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155660 seconds
# INFO:braindecode.experiments.experiment:Epoch 36
# INFO:braindecode.experiments.experiment:train_loss           1.37272
# INFO:braindecode.experiments.experiment:valid_loss           1.56611
# INFO:braindecode.experiments.experiment:test_loss            0.99940
# INFO:braindecode.experiments.experiment:train_misclass       0.40260
# INFO:braindecode.experiments.experiment:valid_misclass       0.57895
# INFO:braindecode.experiments.experiment:test_misclass        0.38889
# INFO:braindecode.experiments.experiment:runtime              0.27293
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155604 seconds
# INFO:braindecode.experiments.experiment:Epoch 37
# INFO:braindecode.experiments.experiment:train_loss           1.20805
# INFO:braindecode.experiments.experiment:valid_loss           1.37971
# INFO:braindecode.experiments.experiment:test_loss            0.89648
# INFO:braindecode.experiments.experiment:train_misclass       0.39827
# INFO:braindecode.experiments.experiment:valid_misclass       0.50877
# INFO:braindecode.experiments.experiment:test_misclass        0.35417
# INFO:braindecode.experiments.experiment:runtime              0.27313
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.508772
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155746 seconds
# INFO:braindecode.experiments.experiment:Epoch 38
# INFO:braindecode.experiments.experiment:train_loss           1.20175
# INFO:braindecode.experiments.experiment:valid_loss           1.37162
# INFO:braindecode.experiments.experiment:test_loss            0.91420
# INFO:braindecode.experiments.experiment:train_misclass       0.38961
# INFO:braindecode.experiments.experiment:valid_misclass       0.50877
# INFO:braindecode.experiments.experiment:test_misclass        0.37153
# INFO:braindecode.experiments.experiment:runtime              0.27360
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.508772
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.156746 seconds
# INFO:braindecode.experiments.experiment:Epoch 39
# INFO:braindecode.experiments.experiment:train_loss           1.28346
# INFO:braindecode.experiments.experiment:valid_loss           1.47015
# INFO:braindecode.experiments.experiment:test_loss            1.00320
# INFO:braindecode.experiments.experiment:train_misclass       0.39827
# INFO:braindecode.experiments.experiment:valid_misclass       0.56140
# INFO:braindecode.experiments.experiment:test_misclass        0.39236
# INFO:braindecode.experiments.experiment:runtime              0.27453
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.156234 seconds
# INFO:braindecode.experiments.experiment:Epoch 40
# INFO:braindecode.experiments.experiment:train_loss           1.23477
# INFO:braindecode.experiments.experiment:valid_loss           1.40128
# INFO:braindecode.experiments.experiment:test_loss            0.90764
# INFO:braindecode.experiments.experiment:train_misclass       0.38528
# INFO:braindecode.experiments.experiment:valid_misclass       0.49123
# INFO:braindecode.experiments.experiment:test_misclass        0.36458
# INFO:braindecode.experiments.experiment:runtime              0.27329
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.491228
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.156027 seconds
# INFO:braindecode.experiments.experiment:Epoch 41
# INFO:braindecode.experiments.experiment:train_loss           1.06279
# INFO:braindecode.experiments.experiment:valid_loss           1.30845
# INFO:braindecode.experiments.experiment:test_loss            0.88093
# INFO:braindecode.experiments.experiment:train_misclass       0.38095
# INFO:braindecode.experiments.experiment:valid_misclass       0.47368
# INFO:braindecode.experiments.experiment:test_misclass        0.34722
# INFO:braindecode.experiments.experiment:runtime              0.27400
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.473684
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.156064 seconds
# INFO:braindecode.experiments.experiment:Epoch 42
# INFO:braindecode.experiments.experiment:train_loss           1.27039
# INFO:braindecode.experiments.experiment:valid_loss           1.44188
# INFO:braindecode.experiments.experiment:test_loss            1.02406
# INFO:braindecode.experiments.experiment:train_misclass       0.37229
# INFO:braindecode.experiments.experiment:valid_misclass       0.54386
# INFO:braindecode.experiments.experiment:test_misclass        0.36111
# INFO:braindecode.experiments.experiment:runtime              0.27395
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155763 seconds
# INFO:braindecode.experiments.experiment:Epoch 43
# INFO:braindecode.experiments.experiment:train_loss           1.31009
# INFO:braindecode.experiments.experiment:valid_loss           1.45510
# INFO:braindecode.experiments.experiment:test_loss            0.93688
# INFO:braindecode.experiments.experiment:train_misclass       0.38961
# INFO:braindecode.experiments.experiment:valid_misclass       0.52632
# INFO:braindecode.experiments.experiment:test_misclass        0.34722
# INFO:braindecode.experiments.experiment:runtime              0.27320
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.156176 seconds
# INFO:braindecode.experiments.experiment:Epoch 44
# INFO:braindecode.experiments.experiment:train_loss           1.01713
# INFO:braindecode.experiments.experiment:valid_loss           1.24716
# INFO:braindecode.experiments.experiment:test_loss            0.82066
# INFO:braindecode.experiments.experiment:train_misclass       0.37229
# INFO:braindecode.experiments.experiment:valid_misclass       0.45614
# INFO:braindecode.experiments.experiment:test_misclass        0.31250
# INFO:braindecode.experiments.experiment:runtime              0.27336
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.456140
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155956 seconds
# INFO:braindecode.experiments.experiment:Epoch 45
# INFO:braindecode.experiments.experiment:train_loss           1.13249
# INFO:braindecode.experiments.experiment:valid_loss           1.33542
# INFO:braindecode.experiments.experiment:test_loss            0.93148
# INFO:braindecode.experiments.experiment:train_misclass       0.36797
# INFO:braindecode.experiments.experiment:valid_misclass       0.50877
# INFO:braindecode.experiments.experiment:test_misclass        0.36806
# INFO:braindecode.experiments.experiment:runtime              0.27380
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155517 seconds
# INFO:braindecode.experiments.experiment:Epoch 46
# INFO:braindecode.experiments.experiment:train_loss           1.18024
# INFO:braindecode.experiments.experiment:valid_loss           1.38251
# INFO:braindecode.experiments.experiment:test_loss            1.00800
# INFO:braindecode.experiments.experiment:train_misclass       0.36364
# INFO:braindecode.experiments.experiment:valid_misclass       0.50877
# INFO:braindecode.experiments.experiment:test_misclass        0.36458
# INFO:braindecode.experiments.experiment:runtime              0.27290
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155600 seconds
# INFO:braindecode.experiments.experiment:Epoch 47
# INFO:braindecode.experiments.experiment:train_loss           1.25686
# INFO:braindecode.experiments.experiment:valid_loss           1.41540
# INFO:braindecode.experiments.experiment:test_loss            0.80950
# INFO:braindecode.experiments.experiment:train_misclass       0.41126
# INFO:braindecode.experiments.experiment:valid_misclass       0.47368
# INFO:braindecode.experiments.experiment:test_misclass        0.30208
# INFO:braindecode.experiments.experiment:runtime              0.27274
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.156100 seconds
# INFO:braindecode.experiments.experiment:Epoch 48
# INFO:braindecode.experiments.experiment:train_loss           0.86658
# INFO:braindecode.experiments.experiment:valid_loss           1.13033
# INFO:braindecode.experiments.experiment:test_loss            0.86879
# INFO:braindecode.experiments.experiment:train_misclass       0.33766
# INFO:braindecode.experiments.experiment:valid_misclass       0.43860
# INFO:braindecode.experiments.experiment:test_misclass        0.34028
# INFO:braindecode.experiments.experiment:runtime              0.27337
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.438596
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155641 seconds
# INFO:braindecode.experiments.experiment:Epoch 49
# INFO:braindecode.experiments.experiment:train_loss           1.14352
# INFO:braindecode.experiments.experiment:valid_loss           1.35078
# INFO:braindecode.experiments.experiment:test_loss            0.89985
# INFO:braindecode.experiments.experiment:train_misclass       0.37229
# INFO:braindecode.experiments.experiment:valid_misclass       0.49123
# INFO:braindecode.experiments.experiment:test_misclass        0.34375
# INFO:braindecode.experiments.experiment:runtime              0.27341
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 0.155062 seconds
# INFO:braindecode.experiments.experiment:Epoch 50
# INFO:braindecode.experiments.experiment:train_loss           1.00192
# INFO:braindecode.experiments.experiment:valid_loss           1.23397
# INFO:braindecode.experiments.experiment:test_loss            0.88063
# INFO:braindecode.experiments.experiment:train_misclass       0.35498
# INFO:braindecode.experiments.experiment:valid_misclass       0.43860
# INFO:braindecode.experiments.experiment:test_misclass        0.32986
# INFO:braindecode.experiments.experiment:runtime              0.27234
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.438596

# %% [markdown]
# Ok, better already :) Now I would deem this ready for a more systematic comparison....

# %% [markdown]
# ## Stuff just for me (Robin) :)

# %%
# %%capture
import scikits.samplerate
import os
import site
site.addsitedir('/home/schirrmr/.local/lib/python2.7/site-packages/')
site.addsitedir('/usr/lib/pymodules/python2.7/')
os.sys.path.insert(0, '/home/schirrmr/braindecode/code/')
# %cd /home/schirrmr/braindecode/code/braindecode/
assert 'THEANO_FLAGS' in os.environ
# switch to cpu
#os.environ['THEANO_FLAGS'] = 'floatX=float32,device=cpu,nvcc.fastmath=True'
