# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import theano
import matplotlib
from matplotlib import pyplot
from matplotlib import cm
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg' 
matplotlib.rcParams['figure.figsize'] = (12.0, 1.0)
matplotlib.rcParams['font.size'] = 7

import matplotlib.lines as mlines
import seaborn
seaborn.set_style('darkgrid')
import logging 
log = logging.getLogger()
log.setLevel('DEBUG')
# Out:
# Using gpu device 0: GeForce GTX 780 (CNMeM is disabled)

# %% [markdown]
# # Experiment Tutorial

# %% [markdown]
# In this tutorial, we will run an experiment on the BCI Competition IV dataset.
# We will look at how to run a normal experiment and how to train over smaller windows cut out of the trials.
#
# We have these four steps for the experiment:
#
# 1. load the dataset
# 2. create the layers
# 3. configure the experiment
# 4. run the experiment
#
# We assume you have the BCI Competition Data under ```data/bci-competition-iv/2a-combined/```.

# %% [markdown]
# ## Load the dataset
#
# When loading the dataset, we have the following choiches to make:
#
# * trial window => segment_ival
# * what preprocessings to apply to the continuous signal, e.g. resampling, highpass etc.
# * what sensors to use (not implemented atm for BCI competition set, since there are only 22 EEG sensors anyways :))

# %%
from braindecode.datasets.signal_processor import SignalProcessor
from braindecode.datasets.loaders import BCICompetition4Set2A
from braindecode.datasets.raw import CleanSignalMatrix
from braindecode.datahandling.batch_iteration import WindowsIterator
from braindecode.veganlasagne.monitors import WindowMisclassMonitor
from braindecode.mywyrm.clean import NoCleaner
from braindecode.mywyrm.processing import resample_cnt, highpass_cnt

signal_processor = SignalProcessor(set_loader=BCICompetition4Set2A(
            filename="data/bci-competition-iv/2a-combined/A03TE.mat"),
    segment_ival=[0, 4000], 
    cnt_preprocessors=[[resample_cnt,dict(newfs=150)],
                       [highpass_cnt, dict(low_cut_off_hz=0.5)]])

dataset = CleanSignalMatrix(cleaner=NoCleaner(), 
                                  signal_processor=signal_processor, 
                                  sensor_names='all')
dataset.load()
# Out:
# INFO:braindecode.datasets.raw:Loading set...
# INFO:braindecode.datasets.raw:Cleaning set...
# INFO:braindecode.datasets.raw:Preprocessing set...
# INFO:braindecode.datasets.raw:Loaded clean data with shape (576, 600, 22).
# INFO:braindecode.datasets.raw:Loaded dataset with shape: (576, 22, 600, 1)

# %% [markdown]
# ## Create Layers
#
# Here we will use the raw net, we set the input shape correctly from the loaded dataset. Note that we give names to the layers with weights, we need them later to constrain their norms.

# %%
import lasagne
from numpy.random import RandomState
from lasagne.layers import DenseLayer,DropoutLayer,Conv2DLayer, DimshuffleLayer, InputLayer, NonlinearityLayer
from braindecode.veganlasagne.layers import Conv2DAllColsLayer
from braindecode.veganlasagne.pool import SumPool2dLayer
lasagne.random.set_rng(RandomState(9859295))
in_shape = list(dataset.get_topological_view().shape)
in_shape[0] = None # to allow arbitrary sizes of batches
in_layer = InputLayer(shape=in_shape)
network = DimshuffleLayer(incoming= in_layer, pattern=[0, 3, 2, 1])
network = Conv2DLayer(incoming=network, num_filters=40,
    filter_size=[15, 1], nonlinearity=lasagne.nonlinearities.identity, name='time_conv')
network = DropoutLayer(incoming=network, p=0.5)
network = Conv2DAllColsLayer(incoming=network, num_filters=40,
    filter_size=[1, -1], nonlinearity=theano.tensor.sqr, name='spat_conv')
network = SumPool2dLayer(incoming=network, pool_size=[50, 1],
    stride=[10, 1], mode='average_exc_pad')
network = NonlinearityLayer(incoming=network, 
    nonlinearity=theano.tensor.log)
network = DropoutLayer(incoming=network, p=0.5)
network = DenseLayer(incoming=network,
    num_units=4, nonlinearity=lasagne.nonlinearities.softmax, name='final_dense')

# %% [markdown]
# ## Configure the Experiment

# %% [markdown]
# ### Dataset Splitting

# %% [markdown]
# We first look at the how to split our dataset into train, valid and test set. We split this dataset at a fixed trial, nr. 288, into train and test. Since the dataset has 576 trials, this exactly splits it into half training and half test as in the original BCI Competition.
# We use 20% of the **training trials** as our validation set. The validation trials are always at the end of the training set.

# %%
from braindecode.datahandling.splitters import FixedTrialSplitter
dataset_splitter=FixedTrialSplitter(n_train_trials=288, valid_set_fraction=0.2)

# %% [markdown]
# ### Dataset Preprocessing

# %% [markdown]
# We preprocess our dataset along the channel axis. We use online standardization so it could also be applied in the same way for an online experiment.

# %%
from braindecode.datahandling.preprocessing import OnlineAxiswiseStandardize
preprocessor = OnlineAxiswiseStandardize(axis=['c', 1]) # the 1 is not important as the 1 dim (form bc01) is empty...

# %% [markdown]
# ### Batch Iteration

# %% [markdown]
# We iterate over balanced batches, so batches are gauranteed to have a maximum size difference of 1. The way this is implemented, batches can get slightly bigger than the given batch size.

# %%
from braindecode.datahandling.batch_iteration import BalancedBatchIterator
dataset_iterator = BalancedBatchIterator(batch_size=60)

# %% [markdown]
# ### Loss and Updates

# %% [markdown]
# Our loss is the categorical cross entropy and updates will be computed using Adam.
# We will norm constraints, that means the units will be constrained to not have a larger sum of squares than specified.

# %%
from braindecode.veganlasagne.update_modifiers import MaxNormConstraint
updates_var_func=lasagne.updates.adam
loss_var_func= lasagne.objectives.categorical_crossentropy

updates_modifier = MaxNormConstraint({
            'time_conv': 2.0,
            'spat_conv': 2.0,
            'final_dense': 0.5})

# %% [markdown]
# ### Stopping and Monitors

# %% [markdown]
# Finally, we have to decide for a stopping and what values to monitor. We monitor loss and misclass (actually we always have to monitor them for the experiment to work) as well as the runtime per epoch.
# For stopping, we stop after 10 epochs.

# %%
from braindecode.veganlasagne.monitors import LossMonitor, MisclassMonitor, RuntimeMonitor
from braindecode.veganlasagne.stopping import MaxEpochs
from braindecode.experiments.experiment import Experiment
stop_criterion = MaxEpochs(num_epochs=20)
monitors=[LossMonitor(), MisclassMonitor(), RuntimeMonitor()]

exp = Experiment(network, dataset, dataset_splitter, preprocessor,
          dataset_iterator, loss_var_func, updates_var_func, updates_modifier, monitors, stop_criterion)

# %% [markdown]
# ## Run the Experiment

# %% [markdown]
# We setup the experiment and run it.

# %%
exp.setup()
exp.run()
# Out:
# INFO:braindecode.experiments.experiment:Layers...
# INFO:braindecode.experiments.experiment:InputLayer
# INFO:braindecode.experiments.experiment:[None, 22, 600, 1]
# INFO:braindecode.experiments.experiment:DimshuffleLayer
# INFO:braindecode.experiments.experiment:(None, 1, 600, 22)
# INFO:braindecode.experiments.experiment:Conv2DLayer
# INFO:braindecode.experiments.experiment:(None, 40, 586, 22)
# INFO:braindecode.experiments.experiment:DropoutLayer
# INFO:braindecode.experiments.experiment:(None, 40, 586, 22)
# INFO:braindecode.experiments.experiment:Conv2DAllColsLayer
# INFO:braindecode.experiments.experiment:(None, 40, 586, 1)
# INFO:braindecode.experiments.experiment:SumPool2dLayer
# INFO:braindecode.experiments.experiment:(None, 40, 54, 1)
# INFO:braindecode.experiments.experiment:NonlinearityLayer
# INFO:braindecode.experiments.experiment:(None, 40, 54, 1)
# INFO:braindecode.experiments.experiment:DropoutLayer
# INFO:braindecode.experiments.experiment:(None, 40, 54, 1)
# INFO:braindecode.experiments.experiment:DenseLayer
# INFO:braindecode.experiments.experiment:(None, 4)
# INFO:braindecode.experiments.experiment:Create theano functions...
# INFO:braindecode.veganlasagne.update_modifiers:Constraining time_conv to norm 2.00
# INFO:braindecode.veganlasagne.update_modifiers:Constraining spat_conv to norm 2.00
# INFO:braindecode.veganlasagne.update_modifiers:Constraining final_dense to norm 0.50
# INFO:braindecode.experiments.experiment:Done.
# INFO:braindecode.experiments.experiment:Run until first stop...
# INFO:braindecode.experiments.experiment:Epoch 0
# INFO:braindecode.experiments.experiment:train_loss           1.64055
# INFO:braindecode.experiments.experiment:valid_loss           1.65920
# INFO:braindecode.experiments.experiment:test_loss            1.60042
# INFO:braindecode.experiments.experiment:train_misclass       0.75325
# INFO:braindecode.experiments.experiment:valid_misclass       0.73684
# INFO:braindecode.experiments.experiment:test_misclass        0.75347
# INFO:braindecode.experiments.experiment:runtime              0.00000
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.269558 seconds
# INFO:braindecode.experiments.experiment:Epoch 1
# INFO:braindecode.experiments.experiment:train_loss           1.48329
# INFO:braindecode.experiments.experiment:valid_loss           1.44297
# INFO:braindecode.experiments.experiment:test_loss            1.47442
# INFO:braindecode.experiments.experiment:train_misclass       0.77922
# INFO:braindecode.experiments.experiment:valid_misclass       0.75439
# INFO:braindecode.experiments.experiment:test_misclass        0.76736
# INFO:braindecode.experiments.experiment:runtime              0.48349
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.267121 seconds
# INFO:braindecode.experiments.experiment:Epoch 2
# INFO:braindecode.experiments.experiment:train_loss           1.77340
# INFO:braindecode.experiments.experiment:valid_loss           1.75056
# INFO:braindecode.experiments.experiment:test_loss            1.77169
# INFO:braindecode.experiments.experiment:train_misclass       0.71861
# INFO:braindecode.experiments.experiment:valid_misclass       0.78947
# INFO:braindecode.experiments.experiment:test_misclass        0.75000
# INFO:braindecode.experiments.experiment:runtime              0.46680
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.267926 seconds
# INFO:braindecode.experiments.experiment:Epoch 3
# INFO:braindecode.experiments.experiment:train_loss           2.05418
# INFO:braindecode.experiments.experiment:valid_loss           2.10142
# INFO:braindecode.experiments.experiment:test_loss            2.04262
# INFO:braindecode.experiments.experiment:train_misclass       0.73160
# INFO:braindecode.experiments.experiment:valid_misclass       0.78947
# INFO:braindecode.experiments.experiment:test_misclass        0.75347
# INFO:braindecode.experiments.experiment:runtime              0.46656
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.267223 seconds
# INFO:braindecode.experiments.experiment:Epoch 4
# INFO:braindecode.experiments.experiment:train_loss           2.04429
# INFO:braindecode.experiments.experiment:valid_loss           2.10519
# INFO:braindecode.experiments.experiment:test_loss            2.03011
# INFO:braindecode.experiments.experiment:train_misclass       0.73593
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.75347
# INFO:braindecode.experiments.experiment:runtime              0.46647
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.268745 seconds
# INFO:braindecode.experiments.experiment:Epoch 5
# INFO:braindecode.experiments.experiment:train_loss           2.54921
# INFO:braindecode.experiments.experiment:valid_loss           2.61949
# INFO:braindecode.experiments.experiment:test_loss            2.51853
# INFO:braindecode.experiments.experiment:train_misclass       0.74459
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.75000
# INFO:braindecode.experiments.experiment:runtime              0.46628
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.267977 seconds
# INFO:braindecode.experiments.experiment:Epoch 6
# INFO:braindecode.experiments.experiment:train_loss           3.31732
# INFO:braindecode.experiments.experiment:valid_loss           3.34078
# INFO:braindecode.experiments.experiment:test_loss            3.27099
# INFO:braindecode.experiments.experiment:train_misclass       0.74459
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.75347
# INFO:braindecode.experiments.experiment:runtime              0.46696
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270015 seconds
# INFO:braindecode.experiments.experiment:Epoch 7
# INFO:braindecode.experiments.experiment:train_loss           3.58455
# INFO:braindecode.experiments.experiment:valid_loss           3.49026
# INFO:braindecode.experiments.experiment:test_loss            3.55601
# INFO:braindecode.experiments.experiment:train_misclass       0.74459
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.75347
# INFO:braindecode.experiments.experiment:runtime              0.46925
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.269111 seconds
# INFO:braindecode.experiments.experiment:Epoch 8
# INFO:braindecode.experiments.experiment:train_loss           3.52250
# INFO:braindecode.experiments.experiment:valid_loss           3.43185
# INFO:braindecode.experiments.experiment:test_loss            3.47867
# INFO:braindecode.experiments.experiment:train_misclass       0.74459
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.75347
# INFO:braindecode.experiments.experiment:runtime              0.46956
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.267255 seconds
# INFO:braindecode.experiments.experiment:Epoch 9
# INFO:braindecode.experiments.experiment:train_loss           3.67220
# INFO:braindecode.experiments.experiment:valid_loss           3.71124
# INFO:braindecode.experiments.experiment:test_loss            3.57562
# INFO:braindecode.experiments.experiment:train_misclass       0.74459
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.75347
# INFO:braindecode.experiments.experiment:runtime              0.46645
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.268313 seconds
# INFO:braindecode.experiments.experiment:Epoch 10
# INFO:braindecode.experiments.experiment:train_loss           3.36240
# INFO:braindecode.experiments.experiment:valid_loss           3.47680
# INFO:braindecode.experiments.experiment:test_loss            3.26594
# INFO:braindecode.experiments.experiment:train_misclass       0.74459
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.75347
# INFO:braindecode.experiments.experiment:runtime              0.46797
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.268698 seconds
# INFO:braindecode.experiments.experiment:Epoch 11
# INFO:braindecode.experiments.experiment:train_loss           2.76424
# INFO:braindecode.experiments.experiment:valid_loss           2.91918
# INFO:braindecode.experiments.experiment:test_loss            2.69752
# INFO:braindecode.experiments.experiment:train_misclass       0.73593
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.74306
# INFO:braindecode.experiments.experiment:runtime              0.46769
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.269839 seconds
# INFO:braindecode.experiments.experiment:Epoch 12
# INFO:braindecode.experiments.experiment:train_loss           2.89232
# INFO:braindecode.experiments.experiment:valid_loss           3.08954
# INFO:braindecode.experiments.experiment:test_loss            2.80332
# INFO:braindecode.experiments.experiment:train_misclass       0.73160
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.72917
# INFO:braindecode.experiments.experiment:runtime              0.46921
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.268072 seconds
# INFO:braindecode.experiments.experiment:Epoch 13
# INFO:braindecode.experiments.experiment:train_loss           2.68524
# INFO:braindecode.experiments.experiment:valid_loss           2.91324
# INFO:braindecode.experiments.experiment:test_loss            2.59002
# INFO:braindecode.experiments.experiment:train_misclass       0.72294
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.72222
# INFO:braindecode.experiments.experiment:runtime              0.46941
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.267509 seconds
# INFO:braindecode.experiments.experiment:Epoch 14
# INFO:braindecode.experiments.experiment:train_loss           2.17895
# INFO:braindecode.experiments.experiment:valid_loss           2.43070
# INFO:braindecode.experiments.experiment:test_loss            2.11799
# INFO:braindecode.experiments.experiment:train_misclass       0.70130
# INFO:braindecode.experiments.experiment:valid_misclass       0.78947
# INFO:braindecode.experiments.experiment:test_misclass        0.68403
# INFO:braindecode.experiments.experiment:runtime              0.46791
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270711 seconds
# INFO:braindecode.experiments.experiment:Epoch 15
# INFO:braindecode.experiments.experiment:train_loss           2.36325
# INFO:braindecode.experiments.experiment:valid_loss           2.65747
# INFO:braindecode.experiments.experiment:test_loss            2.26528
# INFO:braindecode.experiments.experiment:train_misclass       0.70563
# INFO:braindecode.experiments.experiment:valid_misclass       0.75439
# INFO:braindecode.experiments.experiment:test_misclass        0.69097
# INFO:braindecode.experiments.experiment:runtime              0.47068
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.267704 seconds
# INFO:braindecode.experiments.experiment:Epoch 16
# INFO:braindecode.experiments.experiment:train_loss           2.42623
# INFO:braindecode.experiments.experiment:valid_loss           2.75840
# INFO:braindecode.experiments.experiment:test_loss            2.29890
# INFO:braindecode.experiments.experiment:train_misclass       0.70996
# INFO:braindecode.experiments.experiment:valid_misclass       0.73684
# INFO:braindecode.experiments.experiment:test_misclass        0.67708
# INFO:braindecode.experiments.experiment:runtime              0.46903
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.267567 seconds
# INFO:braindecode.experiments.experiment:Epoch 17
# INFO:braindecode.experiments.experiment:train_loss           1.88073
# INFO:braindecode.experiments.experiment:valid_loss           2.21729
# INFO:braindecode.experiments.experiment:test_loss            1.81180
# INFO:braindecode.experiments.experiment:train_misclass       0.63636
# INFO:braindecode.experiments.experiment:valid_misclass       0.71930
# INFO:braindecode.experiments.experiment:test_misclass        0.63194
# INFO:braindecode.experiments.experiment:runtime              0.46745
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.272530 seconds
# INFO:braindecode.experiments.experiment:Epoch 18
# INFO:braindecode.experiments.experiment:train_loss           1.93027
# INFO:braindecode.experiments.experiment:valid_loss           2.28947
# INFO:braindecode.experiments.experiment:test_loss            1.85291
# INFO:braindecode.experiments.experiment:train_misclass       0.59740
# INFO:braindecode.experiments.experiment:valid_misclass       0.71930
# INFO:braindecode.experiments.experiment:test_misclass        0.60764
# INFO:braindecode.experiments.experiment:runtime              0.47625
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.267708 seconds
# INFO:braindecode.experiments.experiment:Epoch 19
# INFO:braindecode.experiments.experiment:train_loss           1.91284
# INFO:braindecode.experiments.experiment:valid_loss           2.30533
# INFO:braindecode.experiments.experiment:test_loss            1.83463
# INFO:braindecode.experiments.experiment:train_misclass       0.55844
# INFO:braindecode.experiments.experiment:valid_misclass       0.66667
# INFO:braindecode.experiments.experiment:test_misclass        0.57986
# INFO:braindecode.experiments.experiment:runtime              0.46706
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.269303 seconds
# INFO:braindecode.experiments.experiment:Epoch 20
# INFO:braindecode.experiments.experiment:train_loss           1.79267
# INFO:braindecode.experiments.experiment:valid_loss           2.20180
# INFO:braindecode.experiments.experiment:test_loss            1.70959
# INFO:braindecode.experiments.experiment:train_misclass       0.58442
# INFO:braindecode.experiments.experiment:valid_misclass       0.68421
# INFO:braindecode.experiments.experiment:test_misclass        0.54514
# INFO:braindecode.experiments.experiment:runtime              0.46736
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Setup for second stop...
# INFO:braindecode.experiments.experiment:Run until second stop...
# INFO:braindecode.experiments.experiment:Epoch 20
# INFO:braindecode.experiments.experiment:train_loss           2.09400
# INFO:braindecode.experiments.experiment:valid_loss           2.37373
# INFO:braindecode.experiments.experiment:test_loss            1.90956
# INFO:braindecode.experiments.experiment:train_misclass       0.59722
# INFO:braindecode.experiments.experiment:valid_misclass       0.68421
# INFO:braindecode.experiments.experiment:test_misclass        0.57986
# INFO:braindecode.experiments.experiment:runtime              2.32180
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.337827 seconds
# INFO:braindecode.experiments.experiment:Epoch 21
# INFO:braindecode.experiments.experiment:train_loss           2.10057
# INFO:braindecode.experiments.experiment:valid_loss           2.42113
# INFO:braindecode.experiments.experiment:test_loss            1.88027
# INFO:braindecode.experiments.experiment:train_misclass       0.60417
# INFO:braindecode.experiments.experiment:valid_misclass       0.66667
# INFO:braindecode.experiments.experiment:test_misclass        0.56597
# INFO:braindecode.experiments.experiment:runtime              0.55839
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.339713 seconds
# INFO:braindecode.experiments.experiment:Epoch 22
# INFO:braindecode.experiments.experiment:train_loss           1.58521
# INFO:braindecode.experiments.experiment:valid_loss           1.93274
# INFO:braindecode.experiments.experiment:test_loss            1.41722
# INFO:braindecode.experiments.experiment:train_misclass       0.54514
# INFO:braindecode.experiments.experiment:valid_misclass       0.64912
# INFO:braindecode.experiments.experiment:test_misclass        0.47569
# INFO:braindecode.experiments.experiment:runtime              0.55996
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.337827 seconds
# INFO:braindecode.experiments.experiment:Epoch 23
# INFO:braindecode.experiments.experiment:train_loss           1.47570
# INFO:braindecode.experiments.experiment:valid_loss           1.83727
# INFO:braindecode.experiments.experiment:test_loss            1.36848
# INFO:braindecode.experiments.experiment:train_misclass       0.46875
# INFO:braindecode.experiments.experiment:valid_misclass       0.57895
# INFO:braindecode.experiments.experiment:test_misclass        0.44792
# INFO:braindecode.experiments.experiment:runtime              0.55783
# INFO:braindecode.experiments.experiment:

# %% [markdown]
# As you can see from the output, there are two phases.
#
# 1. The experiment first runs until the stop criterion is fulfilled (this stop criterion should normally use the performance on the validation set).
# 2. Then it takes the parameters from the model with the lowest validation misclass. It merges the validation set into the training set and runs until the loss on the validation set is below the loss on the training set at the epoch of the best model. Also it will stop if it has run as many epochs in the second phase as it needed until the lowest validation misclass). This is all hardcoded atm as I am quite happy with this setup :)
#
# In our case, epoch 19 had the lowest validation misclass. In epoch 19, the train loss was 1.91. So it had to reach a validation loss below 1.91 in the second phase, which it did in epoch 23.

# %% [markdown]
# ## Experiment with windows cut out of trials

# %% [markdown]
# We will now use an experiment with windows cut out of trials. First we show the things that remain the same as in the last experiment (except we already change the shape of the input to match our smaller windows).

# %%
lasagne.random.set_rng(RandomState(9859295))
in_shape = list(dataset.get_topological_view().shape)
in_shape[0] = None # to allow arbitrary sizes of batches
in_shape[2] = 300 # we will use windows with 300 samples
in_layer = InputLayer(shape=in_shape)
network = DimshuffleLayer(incoming= in_layer, pattern=[0, 3, 2, 1])
network = Conv2DLayer(incoming=network, num_filters=40,
    filter_size=[15, 1], nonlinearity=lasagne.nonlinearities.identity, name='time_conv')
network = DropoutLayer(incoming=network, p=0.5)
network = Conv2DAllColsLayer(incoming=network, num_filters=40,
    filter_size=[1, -1], nonlinearity=theano.tensor.sqr, name='spat_conv')
network = SumPool2dLayer(incoming=network, pool_size=[50, 1],
    stride=[10, 1], mode='average_exc_pad')
network = NonlinearityLayer(incoming=network, 
    nonlinearity=theano.tensor.log)
network = DropoutLayer(incoming=network, p=0.5)
network = DenseLayer(incoming=network,
    num_units=4, nonlinearity=lasagne.nonlinearities.softmax, name='final_dense')

dataset_splitter=FixedTrialSplitter(n_train_trials=288, valid_set_fraction=0.2)
preprocessor = OnlineAxiswiseStandardize(axis=['c', 1])
updates_var_func=lasagne.updates.adam
loss_var_func= lasagne.objectives.categorical_crossentropy
updates_modifier = MaxNormConstraint({
            'time_conv': 2.0,
            'spat_conv': 2.0,
            'final_dense': 0.5})

# %% [markdown]
# We use a different iterator which will always cut windows out of the trials. We use windows of 300 samples and a stride of 30 samples between the windows
# Also we need to use a different monitor which will take the average over all windows of a trial to compute
# the prediction for that trial. This assures we can make a fair comparison between both training ways.
# To make our early stopping sensible, we also now stop once the valid misclass has not improved for 2 epochs (normally we would use 20 epochs in this example).

# %%
from braindecode.datahandling.batch_iteration import WindowsIterator
from braindecode.veganlasagne.stopping import Or, NoDecrease
from braindecode.veganlasagne.monitors import WindowMisclassMonitor

dataset_iterator = WindowsIterator(n_samples_per_window=300,batch_size=60,
                                   sample_axes_name=0, n_sample_stride=30)

stop_criterion = NoDecrease('valid_misclass', num_epochs=2)

monitors=[LossMonitor(), WindowMisclassMonitor(), RuntimeMonitor()]

# %%
exp = Experiment(network, dataset, dataset_splitter, preprocessor,
          dataset_iterator, loss_var_func, updates_var_func, updates_modifier, monitors, stop_criterion)
exp.setup()
exp.run()
# Out:
# INFO:braindecode.experiments.experiment:Layers...
# INFO:braindecode.experiments.experiment:InputLayer
# INFO:braindecode.experiments.experiment:[None, 22, 300, 1]
# INFO:braindecode.experiments.experiment:DimshuffleLayer
# INFO:braindecode.experiments.experiment:(None, 1, 300, 22)
# INFO:braindecode.experiments.experiment:Conv2DLayer
# INFO:braindecode.experiments.experiment:(None, 40, 286, 22)
# INFO:braindecode.experiments.experiment:DropoutLayer
# INFO:braindecode.experiments.experiment:(None, 40, 286, 22)
# INFO:braindecode.experiments.experiment:Conv2DAllColsLayer
# INFO:braindecode.experiments.experiment:(None, 40, 286, 1)
# INFO:braindecode.experiments.experiment:SumPool2dLayer
# INFO:braindecode.experiments.experiment:(None, 40, 24, 1)
# INFO:braindecode.experiments.experiment:NonlinearityLayer
# INFO:braindecode.experiments.experiment:(None, 40, 24, 1)
# INFO:braindecode.experiments.experiment:DropoutLayer
# INFO:braindecode.experiments.experiment:(None, 40, 24, 1)
# INFO:braindecode.experiments.experiment:DenseLayer
# INFO:braindecode.experiments.experiment:(None, 4)
# INFO:braindecode.experiments.experiment:Create theano functions...
# INFO:braindecode.veganlasagne.update_modifiers:Constraining time_conv to norm 2.00
# INFO:braindecode.veganlasagne.update_modifiers:Constraining spat_conv to norm 2.00
# INFO:braindecode.veganlasagne.update_modifiers:Constraining final_dense to norm 0.50
# INFO:braindecode.experiments.experiment:Done.
# INFO:braindecode.experiments.experiment:Run until first stop...
# INFO:braindecode.experiments.experiment:Epoch 0
# INFO:braindecode.experiments.experiment:train_loss           1.75198
# INFO:braindecode.experiments.experiment:valid_loss           1.84194
# INFO:braindecode.experiments.experiment:test_loss            1.73650
# INFO:braindecode.experiments.experiment:train_misclass       0.76190
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.76042
# INFO:braindecode.experiments.experiment:runtime              0.00000
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 1.420244 seconds
# INFO:braindecode.experiments.experiment:Epoch 1
# INFO:braindecode.experiments.experiment:train_loss           2.04076
# INFO:braindecode.experiments.experiment:valid_loss           2.00170
# INFO:braindecode.experiments.experiment:test_loss            1.95805
# INFO:braindecode.experiments.experiment:train_misclass       0.74459
# INFO:braindecode.experiments.experiment:valid_misclass       0.77193
# INFO:braindecode.experiments.experiment:test_misclass        0.75347
# INFO:braindecode.experiments.experiment:runtime              2.39565
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 1.418457 seconds
# INFO:braindecode.experiments.experiment:Epoch 2
# INFO:braindecode.experiments.experiment:train_loss           1.62472
# INFO:braindecode.experiments.experiment:valid_loss           1.81430
# INFO:braindecode.experiments.experiment:test_loss            1.45297
# INFO:braindecode.experiments.experiment:train_misclass       0.53680
# INFO:braindecode.experiments.experiment:valid_misclass       0.61404
# INFO:braindecode.experiments.experiment:test_misclass        0.47222
# INFO:braindecode.experiments.experiment:runtime              2.38142
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 1.419686 seconds
# INFO:braindecode.experiments.experiment:Epoch 3
# INFO:braindecode.experiments.experiment:train_loss           1.08417
# INFO:braindecode.experiments.experiment:valid_loss           1.33782
# INFO:braindecode.experiments.experiment:test_loss            0.99275
# INFO:braindecode.experiments.experiment:train_misclass       0.41991
# INFO:braindecode.experiments.experiment:valid_misclass       0.50877
# INFO:braindecode.experiments.experiment:test_misclass        0.38194
# INFO:braindecode.experiments.experiment:runtime              2.38262
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 1.419204 seconds
# INFO:braindecode.experiments.experiment:Epoch 4
# INFO:braindecode.experiments.experiment:train_loss           0.81100
# INFO:braindecode.experiments.experiment:valid_loss           1.20423
# INFO:braindecode.experiments.experiment:test_loss            0.97938
# INFO:braindecode.experiments.experiment:train_misclass       0.29870
# INFO:braindecode.experiments.experiment:valid_misclass       0.45614
# INFO:braindecode.experiments.experiment:test_misclass        0.37500
# INFO:braindecode.experiments.experiment:runtime              2.38183
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 1.418858 seconds
# INFO:braindecode.experiments.experiment:Epoch 5
# INFO:braindecode.experiments.experiment:train_loss           0.75112
# INFO:braindecode.experiments.experiment:valid_loss           1.12893
# INFO:braindecode.experiments.experiment:test_loss            0.76178
# INFO:braindecode.experiments.experiment:train_misclass       0.27273
# INFO:braindecode.experiments.experiment:valid_misclass       0.35088
# INFO:braindecode.experiments.experiment:test_misclass        0.27431
# INFO:braindecode.experiments.experiment:runtime              2.38202
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 1.419839 seconds
# INFO:braindecode.experiments.experiment:Epoch 6
# INFO:braindecode.experiments.experiment:train_loss           0.97045
# INFO:braindecode.experiments.experiment:valid_loss           1.41156
# INFO:braindecode.experiments.experiment:test_loss            1.08256
# INFO:braindecode.experiments.experiment:train_misclass       0.32900
# INFO:braindecode.experiments.experiment:valid_misclass       0.47368
# INFO:braindecode.experiments.experiment:test_misclass        0.34375
# INFO:braindecode.experiments.experiment:runtime              2.38268
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 1.419545 seconds
# INFO:braindecode.experiments.experiment:Epoch 7
# INFO:braindecode.experiments.experiment:train_loss           0.81525
# INFO:braindecode.experiments.experiment:valid_loss           1.31976
# INFO:braindecode.experiments.experiment:test_loss            0.97862
# INFO:braindecode.experiments.experiment:train_misclass       0.30303
# INFO:braindecode.experiments.experiment:valid_misclass       0.40351
# INFO:braindecode.experiments.experiment:test_misclass        0.31250
# INFO:braindecode.experiments.experiment:runtime              2.38237
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Setup for second stop...
# INFO:braindecode.experiments.experiment:Run until second stop...
# INFO:braindecode.experiments.experiment:Epoch 6
# INFO:braindecode.experiments.experiment:train_loss           0.87141
# INFO:braindecode.experiments.experiment:valid_loss           1.15506
# INFO:braindecode.experiments.experiment:test_loss            0.78014
# INFO:braindecode.experiments.experiment:train_misclass       0.30556
# INFO:braindecode.experiments.experiment:valid_misclass       0.36842
# INFO:braindecode.experiments.experiment:test_misclass        0.28819
# INFO:braindecode.experiments.experiment:runtime              3.09646
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 1.767654 seconds
# INFO:braindecode.experiments.experiment:Epoch 7
# INFO:braindecode.experiments.experiment:train_loss           0.65917
# INFO:braindecode.experiments.experiment:valid_loss           0.86677
# INFO:braindecode.experiments.experiment:test_loss            0.68336
# INFO:braindecode.experiments.experiment:train_misclass       0.22569
# INFO:braindecode.experiments.experiment:valid_misclass       0.29825
# INFO:braindecode.experiments.experiment:test_misclass        0.24306
# INFO:braindecode.experiments.experiment:runtime              2.81588
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 1.765079 seconds
# INFO:braindecode.experiments.experiment:Epoch 8
# INFO:braindecode.experiments.experiment:train_loss           0.57260
# INFO:braindecode.experiments.experiment:valid_loss           0.78945
# INFO:braindecode.experiments.experiment:test_loss            0.73591
# INFO:braindecode.experiments.experiment:train_misclass       0.18056
# INFO:braindecode.experiments.experiment:valid_misclass       0.29825
# INFO:braindecode.experiments.experiment:test_misclass        0.28125
# INFO:braindecode.experiments.experiment:runtime              2.81277
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 1.764012 seconds
# INFO:braindecode.experiments.experiment:Epoch 9
# INFO:braindecode.experiments.experiment:train_loss           0.64203
# INFO:braindecode.experiments.experiment:valid_loss           0.88044
# INFO:braindecode.experiments.experiment:test_loss            0.81818
# INFO:braindecode.experiments.experiment:train_misclass       0.19792
# INFO:braindecode.experiments.experiment:valid_misclass       0.26316
# INFO:braindecode.experiments.experiment:test_misclass        0.28472
# INFO:braindecode.experiments.experiment:runtime              2.81343
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 1.767232 seconds
# INFO:braindecode.experiments.experiment:Epoch 10
# INFO:braindecode.experiments.experiment:train_loss           0.67066
# INFO:braindecode.experiments.experiment:valid_loss           0.85742
# INFO:braindecode.experiments.experiment:test_loss            0.77500
# INFO:braindecode.experiments.experiment:train_misclass       0.22917
# INFO:braindecode.experiments.experiment:valid_misclass       0.24561
# INFO:braindecode.experiments.experiment:test_misclass        0.27083
# INFO:braindecode.experiments.experiment:runtime              2.81503
# INFO:braindecode.experiments.experiment:

# %% [markdown]
# The epochs are now much slower, which is because there are much more windows than there were trials before (about 10 times more with our parameters).

# %% [markdown]
# ## Experiment with model making predictions for every window

# %% [markdown]
# One disadvantage of the way to use windows out of the trials like that is net does a lot of computations multiple times. Think of the first convolutional layer over time, when being applied to two neighbouring windows, it will do the same computations multiple times.
#
# A different way to make multiple predictions for one trial is to put it into the model explicitly. If we replace the final dense layer by a convolution over time + average  over all convolution regions, every  convolution region has to have a sensible prediction.
#
# I have never done this before, so let's try it :)
# Note the final 3 layers of the network have changed. A filter size of 22 means we are using 22 pooling regions which is again about half of the trial (ignoring border effects).

# %%
from lasagne.layers import GlobalPoolLayer
import theano.tensor as T
lasagne.random.set_rng(RandomState(9859295))
in_shape = list(dataset.get_topological_view().shape)
in_shape[0] = None # to allow arbitrary sizes of batches
in_layer = InputLayer(shape=in_shape)
network = DimshuffleLayer(incoming= in_layer, pattern=[0, 3, 2, 1])
network = Conv2DLayer(incoming=network, num_filters=40,
    filter_size=[15, 1], nonlinearity=lasagne.nonlinearities.identity, name='time_conv')
network = DropoutLayer(incoming=network, p=0.5)
network = Conv2DAllColsLayer(incoming=network, num_filters=40,
    filter_size=[1, -1], nonlinearity=theano.tensor.sqr, name='spat_conv')
network = SumPool2dLayer(incoming=network, pool_size=[50, 1],
    stride=[10, 1], mode='average_exc_pad')
network = NonlinearityLayer(incoming=network, 
    nonlinearity=theano.tensor.log)
network = DropoutLayer(incoming=network, p=0.5)
network = Conv2DLayer(incoming=network,
    num_filters=4, filter_size=[22, 1], nonlinearity=lasagne.nonlinearities.identity, name='final_conv')
network = GlobalPoolLayer(incoming=network, pool_function=T.mean)
network = NonlinearityLayer(incoming=network, nonlinearity=lasagne.nonlinearities.softmax) 



dataset_splitter=FixedTrialSplitter(n_train_trials=288, valid_set_fraction=0.2)
preprocessor = OnlineAxiswiseStandardize(axis=['c', 1])
updates_var_func=lasagne.updates.adam
loss_var_func= lasagne.objectives.categorical_crossentropy
updates_modifier = MaxNormConstraint({
            'time_conv': 2.0,
            'spat_conv': 2.0,
            'final_conv': 2.0})
dataset_iterator = BalancedBatchIterator(batch_size=60)

stop_criterion = NoDecrease('valid_misclass', num_epochs=2)

monitors=[LossMonitor(), MisclassMonitor(), RuntimeMonitor()]
exp = Experiment(network, dataset, dataset_splitter, preprocessor,
          dataset_iterator, loss_var_func, updates_var_func, updates_modifier, monitors, stop_criterion)
exp.setup()
exp.run()
# Out:
# INFO:braindecode.experiments.experiment:Layers...
# INFO:braindecode.experiments.experiment:InputLayer
# INFO:braindecode.experiments.experiment:[None, 22, 600, 1]
# INFO:braindecode.experiments.experiment:DimshuffleLayer
# INFO:braindecode.experiments.experiment:(None, 1, 600, 22)
# INFO:braindecode.experiments.experiment:Conv2DLayer
# INFO:braindecode.experiments.experiment:(None, 40, 586, 22)
# INFO:braindecode.experiments.experiment:DropoutLayer
# INFO:braindecode.experiments.experiment:(None, 40, 586, 22)
# INFO:braindecode.experiments.experiment:Conv2DAllColsLayer
# INFO:braindecode.experiments.experiment:(None, 40, 586, 1)
# INFO:braindecode.experiments.experiment:SumPool2dLayer
# INFO:braindecode.experiments.experiment:(None, 40, 54, 1)
# INFO:braindecode.experiments.experiment:NonlinearityLayer
# INFO:braindecode.experiments.experiment:(None, 40, 54, 1)
# INFO:braindecode.experiments.experiment:DropoutLayer
# INFO:braindecode.experiments.experiment:(None, 40, 54, 1)
# INFO:braindecode.experiments.experiment:Conv2DLayer
# INFO:braindecode.experiments.experiment:(None, 4, 33, 1)
# INFO:braindecode.experiments.experiment:GlobalPoolLayer
# INFO:braindecode.experiments.experiment:(None, 4)
# INFO:braindecode.experiments.experiment:NonlinearityLayer
# INFO:braindecode.experiments.experiment:(None, 4)
# INFO:braindecode.experiments.experiment:Create theano functions...
# INFO:braindecode.veganlasagne.update_modifiers:Constraining time_conv to norm 2.00
# INFO:braindecode.veganlasagne.update_modifiers:Constraining spat_conv to norm 2.00
# INFO:braindecode.veganlasagne.update_modifiers:Constraining final_conv to norm 2.00
# INFO:braindecode.experiments.experiment:Done.
# INFO:braindecode.experiments.experiment:Run until first stop...
# INFO:braindecode.experiments.experiment:Epoch 0
# INFO:braindecode.experiments.experiment:train_loss           1.84469
# INFO:braindecode.experiments.experiment:valid_loss           1.99339
# INFO:braindecode.experiments.experiment:test_loss            1.81431
# INFO:braindecode.experiments.experiment:train_misclass       0.74459
# INFO:braindecode.experiments.experiment:valid_misclass       0.73684
# INFO:braindecode.experiments.experiment:test_misclass        0.75000
# INFO:braindecode.experiments.experiment:runtime              0.00000
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.276647 seconds
# INFO:braindecode.experiments.experiment:Epoch 1
# INFO:braindecode.experiments.experiment:train_loss           2.73759
# INFO:braindecode.experiments.experiment:valid_loss           2.71680
# INFO:braindecode.experiments.experiment:test_loss            2.78567
# INFO:braindecode.experiments.experiment:train_misclass       0.70563
# INFO:braindecode.experiments.experiment:valid_misclass       0.63158
# INFO:braindecode.experiments.experiment:test_misclass        0.67014
# INFO:braindecode.experiments.experiment:runtime              0.49577
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270947 seconds
# INFO:braindecode.experiments.experiment:Epoch 2
# INFO:braindecode.experiments.experiment:train_loss           1.51229
# INFO:braindecode.experiments.experiment:valid_loss           1.52431
# INFO:braindecode.experiments.experiment:test_loss            1.48203
# INFO:braindecode.experiments.experiment:train_misclass       0.77056
# INFO:braindecode.experiments.experiment:valid_misclass       0.70175
# INFO:braindecode.experiments.experiment:test_misclass        0.76736
# INFO:braindecode.experiments.experiment:runtime              0.47244
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270610 seconds
# INFO:braindecode.experiments.experiment:Epoch 3
# INFO:braindecode.experiments.experiment:train_loss           1.65396
# INFO:braindecode.experiments.experiment:valid_loss           1.66298
# INFO:braindecode.experiments.experiment:test_loss            1.59129
# INFO:braindecode.experiments.experiment:train_misclass       0.74892
# INFO:braindecode.experiments.experiment:valid_misclass       0.75439
# INFO:braindecode.experiments.experiment:test_misclass        0.72917
# INFO:braindecode.experiments.experiment:runtime              0.47292
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Setup for second stop...
# INFO:braindecode.experiments.experiment:Run until second stop...
# INFO:braindecode.experiments.experiment:Epoch 2
# INFO:braindecode.experiments.experiment:train_loss           2.72654
# INFO:braindecode.experiments.experiment:valid_loss           2.71233
# INFO:braindecode.experiments.experiment:test_loss            2.77986
# INFO:braindecode.experiments.experiment:train_misclass       0.68403
# INFO:braindecode.experiments.experiment:valid_misclass       0.63158
# INFO:braindecode.experiments.experiment:test_misclass        0.66319
# INFO:braindecode.experiments.experiment:runtime              2.32468
# INFO:braindecode.experiments.experiment:

# %% [markdown]
# We see the speed is much faster but it doesn't seem to learn so much yet, so let's continue training a little longer.

# %%
exp.stop_criterion = MaxEpochs(num_epochs=50)
exp.run_until_early_stop()
# Out:
# INFO:braindecode.experiments.experiment:Epoch 0
# INFO:braindecode.experiments.experiment:train_loss           2.73759
# INFO:braindecode.experiments.experiment:valid_loss           2.71680
# INFO:braindecode.experiments.experiment:test_loss            2.78567
# INFO:braindecode.experiments.experiment:train_misclass       0.70563
# INFO:braindecode.experiments.experiment:valid_misclass       0.63158
# INFO:braindecode.experiments.experiment:test_misclass        0.67014
# INFO:braindecode.experiments.experiment:runtime              0.00000
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271549 seconds
# INFO:braindecode.experiments.experiment:Epoch 1
# INFO:braindecode.experiments.experiment:train_loss           1.44903
# INFO:braindecode.experiments.experiment:valid_loss           1.46609
# INFO:braindecode.experiments.experiment:test_loss            1.43255
# INFO:braindecode.experiments.experiment:train_misclass       0.75325
# INFO:braindecode.experiments.experiment:valid_misclass       0.75439
# INFO:braindecode.experiments.experiment:test_misclass        0.75000
# INFO:braindecode.experiments.experiment:runtime              0.48945
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.272110 seconds
# INFO:braindecode.experiments.experiment:Epoch 2
# INFO:braindecode.experiments.experiment:train_loss           1.46347
# INFO:braindecode.experiments.experiment:valid_loss           1.50779
# INFO:braindecode.experiments.experiment:test_loss            1.43335
# INFO:braindecode.experiments.experiment:train_misclass       0.70996
# INFO:braindecode.experiments.experiment:valid_misclass       0.75439
# INFO:braindecode.experiments.experiment:test_misclass        0.71528
# INFO:braindecode.experiments.experiment:runtime              0.47287
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271911 seconds
# INFO:braindecode.experiments.experiment:Epoch 3
# INFO:braindecode.experiments.experiment:train_loss           1.91452
# INFO:braindecode.experiments.experiment:valid_loss           1.94545
# INFO:braindecode.experiments.experiment:test_loss            1.83231
# INFO:braindecode.experiments.experiment:train_misclass       0.74026
# INFO:braindecode.experiments.experiment:valid_misclass       0.73684
# INFO:braindecode.experiments.experiment:test_misclass        0.73611
# INFO:braindecode.experiments.experiment:runtime              0.47311
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271156 seconds
# INFO:braindecode.experiments.experiment:Epoch 4
# INFO:braindecode.experiments.experiment:train_loss           1.71618
# INFO:braindecode.experiments.experiment:valid_loss           1.76056
# INFO:braindecode.experiments.experiment:test_loss            1.65944
# INFO:braindecode.experiments.experiment:train_misclass       0.67965
# INFO:braindecode.experiments.experiment:valid_misclass       0.63158
# INFO:braindecode.experiments.experiment:test_misclass        0.63889
# INFO:braindecode.experiments.experiment:runtime              0.47280
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270595 seconds
# INFO:braindecode.experiments.experiment:Epoch 5
# INFO:braindecode.experiments.experiment:train_loss           1.91828
# INFO:braindecode.experiments.experiment:valid_loss           1.95571
# INFO:braindecode.experiments.experiment:test_loss            1.80845
# INFO:braindecode.experiments.experiment:train_misclass       0.63203
# INFO:braindecode.experiments.experiment:valid_misclass       0.70175
# INFO:braindecode.experiments.experiment:test_misclass        0.69097
# INFO:braindecode.experiments.experiment:runtime              0.47231
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271912 seconds
# INFO:braindecode.experiments.experiment:Epoch 6
# INFO:braindecode.experiments.experiment:train_loss           1.90850
# INFO:braindecode.experiments.experiment:valid_loss           1.93915
# INFO:braindecode.experiments.experiment:test_loss            1.78852
# INFO:braindecode.experiments.experiment:train_misclass       0.60173
# INFO:braindecode.experiments.experiment:valid_misclass       0.61404
# INFO:braindecode.experiments.experiment:test_misclass        0.62847
# INFO:braindecode.experiments.experiment:runtime              0.47329
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271041 seconds
# INFO:braindecode.experiments.experiment:Epoch 7
# INFO:braindecode.experiments.experiment:train_loss           1.77791
# INFO:braindecode.experiments.experiment:valid_loss           1.83206
# INFO:braindecode.experiments.experiment:test_loss            1.69017
# INFO:braindecode.experiments.experiment:train_misclass       0.58874
# INFO:braindecode.experiments.experiment:valid_misclass       0.66667
# INFO:braindecode.experiments.experiment:test_misclass        0.58681
# INFO:braindecode.experiments.experiment:runtime              0.47271
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.272270 seconds
# INFO:braindecode.experiments.experiment:Epoch 8
# INFO:braindecode.experiments.experiment:train_loss           2.13567
# INFO:braindecode.experiments.experiment:valid_loss           2.21272
# INFO:braindecode.experiments.experiment:test_loss            2.00250
# INFO:braindecode.experiments.experiment:train_misclass       0.60173
# INFO:braindecode.experiments.experiment:valid_misclass       0.61404
# INFO:braindecode.experiments.experiment:test_misclass        0.62847
# INFO:braindecode.experiments.experiment:runtime              0.47298
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271337 seconds
# INFO:braindecode.experiments.experiment:Epoch 9
# INFO:braindecode.experiments.experiment:train_loss           2.37306
# INFO:braindecode.experiments.experiment:valid_loss           2.45813
# INFO:braindecode.experiments.experiment:test_loss            2.19652
# INFO:braindecode.experiments.experiment:train_misclass       0.70563
# INFO:braindecode.experiments.experiment:valid_misclass       0.75439
# INFO:braindecode.experiments.experiment:test_misclass        0.73264
# INFO:braindecode.experiments.experiment:runtime              0.47389
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270669 seconds
# INFO:braindecode.experiments.experiment:Epoch 10
# INFO:braindecode.experiments.experiment:train_loss           2.02783
# INFO:braindecode.experiments.experiment:valid_loss           2.09823
# INFO:braindecode.experiments.experiment:test_loss            1.86306
# INFO:braindecode.experiments.experiment:train_misclass       0.69264
# INFO:braindecode.experiments.experiment:valid_misclass       0.73684
# INFO:braindecode.experiments.experiment:test_misclass        0.70486
# INFO:braindecode.experiments.experiment:runtime              0.47207
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271729 seconds
# INFO:braindecode.experiments.experiment:Epoch 11
# INFO:braindecode.experiments.experiment:train_loss           2.20668
# INFO:braindecode.experiments.experiment:valid_loss           2.30685
# INFO:braindecode.experiments.experiment:test_loss            2.02231
# INFO:braindecode.experiments.experiment:train_misclass       0.64502
# INFO:braindecode.experiments.experiment:valid_misclass       0.70175
# INFO:braindecode.experiments.experiment:test_misclass        0.64583
# INFO:braindecode.experiments.experiment:runtime              0.47290
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270944 seconds
# INFO:braindecode.experiments.experiment:Epoch 12
# INFO:braindecode.experiments.experiment:train_loss           2.46836
# INFO:braindecode.experiments.experiment:valid_loss           2.58793
# INFO:braindecode.experiments.experiment:test_loss            2.24651
# INFO:braindecode.experiments.experiment:train_misclass       0.67100
# INFO:braindecode.experiments.experiment:valid_misclass       0.73684
# INFO:braindecode.experiments.experiment:test_misclass        0.69097
# INFO:braindecode.experiments.experiment:runtime              0.47177
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270694 seconds
# INFO:braindecode.experiments.experiment:Epoch 13
# INFO:braindecode.experiments.experiment:train_loss           2.31002
# INFO:braindecode.experiments.experiment:valid_loss           2.40893
# INFO:braindecode.experiments.experiment:test_loss            2.06416
# INFO:braindecode.experiments.experiment:train_misclass       0.70563
# INFO:braindecode.experiments.experiment:valid_misclass       0.73684
# INFO:braindecode.experiments.experiment:test_misclass        0.69444
# INFO:braindecode.experiments.experiment:runtime              0.47158
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270858 seconds
# INFO:braindecode.experiments.experiment:Epoch 14
# INFO:braindecode.experiments.experiment:train_loss           2.08531
# INFO:braindecode.experiments.experiment:valid_loss           2.20243
# INFO:braindecode.experiments.experiment:test_loss            1.86154
# INFO:braindecode.experiments.experiment:train_misclass       0.55844
# INFO:braindecode.experiments.experiment:valid_misclass       0.63158
# INFO:braindecode.experiments.experiment:test_misclass        0.58681
# INFO:braindecode.experiments.experiment:runtime              0.47182
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271345 seconds
# INFO:braindecode.experiments.experiment:Epoch 15
# INFO:braindecode.experiments.experiment:train_loss           2.20442
# INFO:braindecode.experiments.experiment:valid_loss           2.31642
# INFO:braindecode.experiments.experiment:test_loss            1.93715
# INFO:braindecode.experiments.experiment:train_misclass       0.62338
# INFO:braindecode.experiments.experiment:valid_misclass       0.68421
# INFO:braindecode.experiments.experiment:test_misclass        0.62153
# INFO:braindecode.experiments.experiment:runtime              0.47253
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.272064 seconds
# INFO:braindecode.experiments.experiment:Epoch 16
# INFO:braindecode.experiments.experiment:train_loss           2.48701
# INFO:braindecode.experiments.experiment:valid_loss           2.62800
# INFO:braindecode.experiments.experiment:test_loss            2.15573
# INFO:braindecode.experiments.experiment:train_misclass       0.66667
# INFO:braindecode.experiments.experiment:valid_misclass       0.73684
# INFO:braindecode.experiments.experiment:test_misclass        0.66667
# INFO:braindecode.experiments.experiment:runtime              0.47328
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270848 seconds
# INFO:braindecode.experiments.experiment:Epoch 17
# INFO:braindecode.experiments.experiment:train_loss           2.20431
# INFO:braindecode.experiments.experiment:valid_loss           2.37110
# INFO:braindecode.experiments.experiment:test_loss            1.93303
# INFO:braindecode.experiments.experiment:train_misclass       0.54978
# INFO:braindecode.experiments.experiment:valid_misclass       0.63158
# INFO:braindecode.experiments.experiment:test_misclass        0.55903
# INFO:braindecode.experiments.experiment:runtime              0.47197
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271170 seconds
# INFO:braindecode.experiments.experiment:Epoch 18
# INFO:braindecode.experiments.experiment:train_loss           1.80549
# INFO:braindecode.experiments.experiment:valid_loss           1.94421
# INFO:braindecode.experiments.experiment:test_loss            1.55976
# INFO:braindecode.experiments.experiment:train_misclass       0.54113
# INFO:braindecode.experiments.experiment:valid_misclass       0.59649
# INFO:braindecode.experiments.experiment:test_misclass        0.52778
# INFO:braindecode.experiments.experiment:runtime              0.47190
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270775 seconds
# INFO:braindecode.experiments.experiment:Epoch 19
# INFO:braindecode.experiments.experiment:train_loss           2.32440
# INFO:braindecode.experiments.experiment:valid_loss           2.48392
# INFO:braindecode.experiments.experiment:test_loss            1.95710
# INFO:braindecode.experiments.experiment:train_misclass       0.61905
# INFO:braindecode.experiments.experiment:valid_misclass       0.66667
# INFO:braindecode.experiments.experiment:test_misclass        0.59375
# INFO:braindecode.experiments.experiment:runtime              0.47196
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271510 seconds
# INFO:braindecode.experiments.experiment:Epoch 20
# INFO:braindecode.experiments.experiment:train_loss           2.34529
# INFO:braindecode.experiments.experiment:valid_loss           2.53230
# INFO:braindecode.experiments.experiment:test_loss            1.97347
# INFO:braindecode.experiments.experiment:train_misclass       0.57143
# INFO:braindecode.experiments.experiment:valid_misclass       0.63158
# INFO:braindecode.experiments.experiment:test_misclass        0.56250
# INFO:braindecode.experiments.experiment:runtime              0.47322
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271256 seconds
# INFO:braindecode.experiments.experiment:Epoch 21
# INFO:braindecode.experiments.experiment:train_loss           1.85610
# INFO:braindecode.experiments.experiment:valid_loss           2.04615
# INFO:braindecode.experiments.experiment:test_loss            1.57087
# INFO:braindecode.experiments.experiment:train_misclass       0.51948
# INFO:braindecode.experiments.experiment:valid_misclass       0.61404
# INFO:braindecode.experiments.experiment:test_misclass        0.50000
# INFO:braindecode.experiments.experiment:runtime              0.47269
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.272349 seconds
# INFO:braindecode.experiments.experiment:Epoch 22
# INFO:braindecode.experiments.experiment:train_loss           2.01994
# INFO:braindecode.experiments.experiment:valid_loss           2.20262
# INFO:braindecode.experiments.experiment:test_loss            1.64638
# INFO:braindecode.experiments.experiment:train_misclass       0.56277
# INFO:braindecode.experiments.experiment:valid_misclass       0.63158
# INFO:braindecode.experiments.experiment:test_misclass        0.51042
# INFO:braindecode.experiments.experiment:runtime              0.47466
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271098 seconds
# INFO:braindecode.experiments.experiment:Epoch 23
# INFO:braindecode.experiments.experiment:train_loss           2.13385
# INFO:braindecode.experiments.experiment:valid_loss           2.34594
# INFO:braindecode.experiments.experiment:test_loss            1.73857
# INFO:braindecode.experiments.experiment:train_misclass       0.55411
# INFO:braindecode.experiments.experiment:valid_misclass       0.61404
# INFO:braindecode.experiments.experiment:test_misclass        0.50694
# INFO:braindecode.experiments.experiment:runtime              0.47319
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270200 seconds
# INFO:braindecode.experiments.experiment:Epoch 24
# INFO:braindecode.experiments.experiment:train_loss           1.72140
# INFO:braindecode.experiments.experiment:valid_loss           1.95017
# INFO:braindecode.experiments.experiment:test_loss            1.44064
# INFO:braindecode.experiments.experiment:train_misclass       0.49351
# INFO:braindecode.experiments.experiment:valid_misclass       0.63158
# INFO:braindecode.experiments.experiment:test_misclass        0.48611
# INFO:braindecode.experiments.experiment:runtime              0.47199
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270003 seconds
# INFO:braindecode.experiments.experiment:Epoch 25
# INFO:braindecode.experiments.experiment:train_loss           1.85209
# INFO:braindecode.experiments.experiment:valid_loss           2.06271
# INFO:braindecode.experiments.experiment:test_loss            1.47034
# INFO:braindecode.experiments.experiment:train_misclass       0.54978
# INFO:braindecode.experiments.experiment:valid_misclass       0.59649
# INFO:braindecode.experiments.experiment:test_misclass        0.46875
# INFO:braindecode.experiments.experiment:runtime              0.47174
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271332 seconds
# INFO:braindecode.experiments.experiment:Epoch 26
# INFO:braindecode.experiments.experiment:train_loss           1.93096
# INFO:braindecode.experiments.experiment:valid_loss           2.17383
# INFO:braindecode.experiments.experiment:test_loss            1.54547
# INFO:braindecode.experiments.experiment:train_misclass       0.53247
# INFO:braindecode.experiments.experiment:valid_misclass       0.61404
# INFO:braindecode.experiments.experiment:test_misclass        0.47222
# INFO:braindecode.experiments.experiment:runtime              0.47368
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270892 seconds
# INFO:braindecode.experiments.experiment:Epoch 27
# INFO:braindecode.experiments.experiment:train_loss           1.57696
# INFO:braindecode.experiments.experiment:valid_loss           1.86904
# INFO:braindecode.experiments.experiment:test_loss            1.36052
# INFO:braindecode.experiments.experiment:train_misclass       0.46753
# INFO:braindecode.experiments.experiment:valid_misclass       0.63158
# INFO:braindecode.experiments.experiment:test_misclass        0.47569
# INFO:braindecode.experiments.experiment:runtime              0.47195
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271625 seconds
# INFO:braindecode.experiments.experiment:Epoch 28
# INFO:braindecode.experiments.experiment:train_loss           1.77688
# INFO:braindecode.experiments.experiment:valid_loss           2.02453
# INFO:braindecode.experiments.experiment:test_loss            1.39202
# INFO:braindecode.experiments.experiment:train_misclass       0.53680
# INFO:braindecode.experiments.experiment:valid_misclass       0.57895
# INFO:braindecode.experiments.experiment:test_misclass        0.44444
# INFO:braindecode.experiments.experiment:runtime              0.47249
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270945 seconds
# INFO:braindecode.experiments.experiment:Epoch 29
# INFO:braindecode.experiments.experiment:train_loss           1.60196
# INFO:braindecode.experiments.experiment:valid_loss           1.86002
# INFO:braindecode.experiments.experiment:test_loss            1.28306
# INFO:braindecode.experiments.experiment:train_misclass       0.48918
# INFO:braindecode.experiments.experiment:valid_misclass       0.56140
# INFO:braindecode.experiments.experiment:test_misclass        0.44097
# INFO:braindecode.experiments.experiment:runtime              0.47248
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271648 seconds
# INFO:braindecode.experiments.experiment:Epoch 30
# INFO:braindecode.experiments.experiment:train_loss           1.50837
# INFO:braindecode.experiments.experiment:valid_loss           1.85400
# INFO:braindecode.experiments.experiment:test_loss            1.33637
# INFO:braindecode.experiments.experiment:train_misclass       0.43723
# INFO:braindecode.experiments.experiment:valid_misclass       0.63158
# INFO:braindecode.experiments.experiment:test_misclass        0.45139
# INFO:braindecode.experiments.experiment:runtime              0.47331
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271163 seconds
# INFO:braindecode.experiments.experiment:Epoch 31
# INFO:braindecode.experiments.experiment:train_loss           1.83198
# INFO:braindecode.experiments.experiment:valid_loss           2.11381
# INFO:braindecode.experiments.experiment:test_loss            1.39626
# INFO:braindecode.experiments.experiment:train_misclass       0.52814
# INFO:braindecode.experiments.experiment:valid_misclass       0.57895
# INFO:braindecode.experiments.experiment:test_misclass        0.44792
# INFO:braindecode.experiments.experiment:runtime              0.47299
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.269905 seconds
# INFO:braindecode.experiments.experiment:Epoch 32
# INFO:braindecode.experiments.experiment:train_loss           1.31201
# INFO:braindecode.experiments.experiment:valid_loss           1.60656
# INFO:braindecode.experiments.experiment:test_loss            1.10145
# INFO:braindecode.experiments.experiment:train_misclass       0.41991
# INFO:braindecode.experiments.experiment:valid_misclass       0.56140
# INFO:braindecode.experiments.experiment:test_misclass        0.39583
# INFO:braindecode.experiments.experiment:runtime              0.47177
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270882 seconds
# INFO:braindecode.experiments.experiment:Epoch 33
# INFO:braindecode.experiments.experiment:train_loss           1.60783
# INFO:braindecode.experiments.experiment:valid_loss           1.98932
# INFO:braindecode.experiments.experiment:test_loss            1.39166
# INFO:braindecode.experiments.experiment:train_misclass       0.44589
# INFO:braindecode.experiments.experiment:valid_misclass       0.59649
# INFO:braindecode.experiments.experiment:test_misclass        0.45139
# INFO:braindecode.experiments.experiment:runtime              0.47232
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271479 seconds
# INFO:braindecode.experiments.experiment:Epoch 34
# INFO:braindecode.experiments.experiment:train_loss           1.57710
# INFO:braindecode.experiments.experiment:valid_loss           1.87907
# INFO:braindecode.experiments.experiment:test_loss            1.22024
# INFO:braindecode.experiments.experiment:train_misclass       0.48918
# INFO:braindecode.experiments.experiment:valid_misclass       0.52632
# INFO:braindecode.experiments.experiment:test_misclass        0.40278
# INFO:braindecode.experiments.experiment:runtime              0.47326
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270870 seconds
# INFO:braindecode.experiments.experiment:Epoch 35
# INFO:braindecode.experiments.experiment:train_loss           1.40377
# INFO:braindecode.experiments.experiment:valid_loss           1.72079
# INFO:braindecode.experiments.experiment:test_loss            1.17091
# INFO:braindecode.experiments.experiment:train_misclass       0.42424
# INFO:braindecode.experiments.experiment:valid_misclass       0.56140
# INFO:braindecode.experiments.experiment:test_misclass        0.38889
# INFO:braindecode.experiments.experiment:runtime              0.47348
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271034 seconds
# INFO:braindecode.experiments.experiment:Epoch 36
# INFO:braindecode.experiments.experiment:train_loss           1.46921
# INFO:braindecode.experiments.experiment:valid_loss           1.81708
# INFO:braindecode.experiments.experiment:test_loss            1.25656
# INFO:braindecode.experiments.experiment:train_misclass       0.42424
# INFO:braindecode.experiments.experiment:valid_misclass       0.54386
# INFO:braindecode.experiments.experiment:test_misclass        0.39583
# INFO:braindecode.experiments.experiment:runtime              0.47201
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.272084 seconds
# INFO:braindecode.experiments.experiment:Epoch 37
# INFO:braindecode.experiments.experiment:train_loss           1.32020
# INFO:braindecode.experiments.experiment:valid_loss           1.61548
# INFO:braindecode.experiments.experiment:test_loss            1.06023
# INFO:braindecode.experiments.experiment:train_misclass       0.41991
# INFO:braindecode.experiments.experiment:valid_misclass       0.52632
# INFO:braindecode.experiments.experiment:test_misclass        0.35764
# INFO:braindecode.experiments.experiment:runtime              0.47281
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270856 seconds
# INFO:braindecode.experiments.experiment:Epoch 38
# INFO:braindecode.experiments.experiment:train_loss           1.18635
# INFO:braindecode.experiments.experiment:valid_loss           1.48908
# INFO:braindecode.experiments.experiment:test_loss            0.98498
# INFO:braindecode.experiments.experiment:train_misclass       0.40260
# INFO:braindecode.experiments.experiment:valid_misclass       0.52632
# INFO:braindecode.experiments.experiment:test_misclass        0.34028
# INFO:braindecode.experiments.experiment:runtime              0.47245
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271543 seconds
# INFO:braindecode.experiments.experiment:Epoch 39
# INFO:braindecode.experiments.experiment:train_loss           1.42911
# INFO:braindecode.experiments.experiment:valid_loss           1.78873
# INFO:braindecode.experiments.experiment:test_loss            1.23754
# INFO:braindecode.experiments.experiment:train_misclass       0.39827
# INFO:braindecode.experiments.experiment:valid_misclass       0.56140
# INFO:braindecode.experiments.experiment:test_misclass        0.38542
# INFO:braindecode.experiments.experiment:runtime              0.47447
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270251 seconds
# INFO:braindecode.experiments.experiment:Epoch 40
# INFO:braindecode.experiments.experiment:train_loss           1.22691
# INFO:braindecode.experiments.experiment:valid_loss           1.57599
# INFO:braindecode.experiments.experiment:test_loss            1.08156
# INFO:braindecode.experiments.experiment:train_misclass       0.39394
# INFO:braindecode.experiments.experiment:valid_misclass       0.56140
# INFO:braindecode.experiments.experiment:test_misclass        0.36111
# INFO:braindecode.experiments.experiment:runtime              0.47128
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270935 seconds
# INFO:braindecode.experiments.experiment:Epoch 41
# INFO:braindecode.experiments.experiment:train_loss           1.10523
# INFO:braindecode.experiments.experiment:valid_loss           1.46505
# INFO:braindecode.experiments.experiment:test_loss            0.96490
# INFO:braindecode.experiments.experiment:train_misclass       0.39827
# INFO:braindecode.experiments.experiment:valid_misclass       0.49123
# INFO:braindecode.experiments.experiment:test_misclass        0.35417
# INFO:braindecode.experiments.experiment:runtime              0.47190
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271268 seconds
# INFO:braindecode.experiments.experiment:Epoch 42
# INFO:braindecode.experiments.experiment:train_loss           1.33216
# INFO:braindecode.experiments.experiment:valid_loss           1.68982
# INFO:braindecode.experiments.experiment:test_loss            1.16734
# INFO:braindecode.experiments.experiment:train_misclass       0.39394
# INFO:braindecode.experiments.experiment:valid_misclass       0.56140
# INFO:braindecode.experiments.experiment:test_misclass        0.37500
# INFO:braindecode.experiments.experiment:runtime              0.47238
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271331 seconds
# INFO:braindecode.experiments.experiment:Epoch 43
# INFO:braindecode.experiments.experiment:train_loss           1.23018
# INFO:braindecode.experiments.experiment:valid_loss           1.57849
# INFO:braindecode.experiments.experiment:test_loss            1.10031
# INFO:braindecode.experiments.experiment:train_misclass       0.38961
# INFO:braindecode.experiments.experiment:valid_misclass       0.56140
# INFO:braindecode.experiments.experiment:test_misclass        0.36111
# INFO:braindecode.experiments.experiment:runtime              0.47297
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.271256 seconds
# INFO:braindecode.experiments.experiment:Epoch 44
# INFO:braindecode.experiments.experiment:train_loss           1.09207
# INFO:braindecode.experiments.experiment:valid_loss           1.43025
# INFO:braindecode.experiments.experiment:test_loss            0.90248
# INFO:braindecode.experiments.experiment:train_misclass       0.39827
# INFO:braindecode.experiments.experiment:valid_misclass       0.49123
# INFO:braindecode.experiments.experiment:test_misclass        0.33681
# INFO:braindecode.experiments.experiment:runtime              0.47360
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.269486 seconds
# INFO:braindecode.experiments.experiment:Epoch 45
# INFO:braindecode.experiments.experiment:train_loss           1.18207
# INFO:braindecode.experiments.experiment:valid_loss           1.54536
# INFO:braindecode.experiments.experiment:test_loss            1.04503
# INFO:braindecode.experiments.experiment:train_misclass       0.38095
# INFO:braindecode.experiments.experiment:valid_misclass       0.52632
# INFO:braindecode.experiments.experiment:test_misclass        0.35069
# INFO:braindecode.experiments.experiment:runtime              0.47152
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270443 seconds
# INFO:braindecode.experiments.experiment:Epoch 46
# INFO:braindecode.experiments.experiment:train_loss           1.17489
# INFO:braindecode.experiments.experiment:valid_loss           1.56092
# INFO:braindecode.experiments.experiment:test_loss            1.10826
# INFO:braindecode.experiments.experiment:train_misclass       0.37229
# INFO:braindecode.experiments.experiment:valid_misclass       0.56140
# INFO:braindecode.experiments.experiment:test_misclass        0.36111
# INFO:braindecode.experiments.experiment:runtime              0.47162
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270119 seconds
# INFO:braindecode.experiments.experiment:Epoch 47
# INFO:braindecode.experiments.experiment:train_loss           1.38423
# INFO:braindecode.experiments.experiment:valid_loss           1.70433
# INFO:braindecode.experiments.experiment:test_loss            1.06340
# INFO:braindecode.experiments.experiment:train_misclass       0.42857
# INFO:braindecode.experiments.experiment:valid_misclass       0.50877
# INFO:braindecode.experiments.experiment:test_misclass        0.33681
# INFO:braindecode.experiments.experiment:runtime              0.47299
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270441 seconds
# INFO:braindecode.experiments.experiment:Epoch 48
# INFO:braindecode.experiments.experiment:train_loss           0.90093
# INFO:braindecode.experiments.experiment:valid_loss           1.27565
# INFO:braindecode.experiments.experiment:test_loss            0.82943
# INFO:braindecode.experiments.experiment:train_misclass       0.35065
# INFO:braindecode.experiments.experiment:valid_misclass       0.43860
# INFO:braindecode.experiments.experiment:test_misclass        0.29861
# INFO:braindecode.experiments.experiment:runtime              0.47311
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270758 seconds
# INFO:braindecode.experiments.experiment:Epoch 49
# INFO:braindecode.experiments.experiment:train_loss           1.08015
# INFO:braindecode.experiments.experiment:valid_loss           1.47101
# INFO:braindecode.experiments.experiment:test_loss            0.99955
# INFO:braindecode.experiments.experiment:train_misclass       0.36797
# INFO:braindecode.experiments.experiment:valid_misclass       0.50877
# INFO:braindecode.experiments.experiment:test_misclass        0.33333
# INFO:braindecode.experiments.experiment:runtime              0.47375
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates this epoch: 0.270719 seconds
# INFO:braindecode.experiments.experiment:Epoch 50
# INFO:braindecode.experiments.experiment:train_loss           1.16104
# INFO:braindecode.experiments.experiment:valid_loss           1.50542
# INFO:braindecode.experiments.experiment:test_loss            1.00579
# INFO:braindecode.experiments.experiment:train_misclass       0.38095
# INFO:braindecode.experiments.experiment:valid_misclass       0.52632
# INFO:braindecode.experiments.experiment:test_misclass        0.32986
# INFO:braindecode.experiments.experiment:runtime              0.47415
# INFO:braindecode.experiments.experiment:

# %% [markdown]
# Ok, better already :) Now I would deem this ready for a more systematic comparison....

# %% [markdown]
# ## Stuff just for me (Robin) :)

# %%
# %%capture
import os
import site
site.addsitedir('/home/schirrmr/.local/lib/python2.7/site-packages/')
site.addsitedir('/usr/lib/pymodules/python2.7/')
os.sys.path.insert(0, '/home/schirrmr/braindecode/code/')
# %cd /home/schirrmr/braindecode/code/braindecode/
assert 'THEANO_FLAGS' in os.environ
# switch to cpu
#os.environ['THEANO_FLAGS'] = 'floatX=float32,device=cpu,nvcc.fastmath=True'
