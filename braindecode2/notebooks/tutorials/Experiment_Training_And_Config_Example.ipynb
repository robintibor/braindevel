# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import theano
import matplotlib
from matplotlib import pyplot
from matplotlib import cm
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg' 
matplotlib.rcParams['figure.figsize'] = (12.0, 1.0)
matplotlib.rcParams['font.size'] = 7

import matplotlib.lines as mlines
import seaborn
seaborn.set_style('darkgrid')
import logging 
log = logging.getLogger()
log.setLevel('DEBUG')
# Out:
# Using gpu device 0: GeForce GTX TITAN Black (CNMeM is disabled, CuDNN 3007)

# %% [markdown]
# # Experiment Tutorial

# %% [markdown]
# In this tutorial, we will run an experiment to train a model for online BCI decoding.
#
# We have these five steps for the experiment:
#
# 1. Setup the dataset
# 2. Setup model
# 3. Setup data splitting and iteration
# 4. Setup other experiment parameters (loss, optimizater, monitoring etc.)
# 5. Run the experiment :)
#
# You have to adjust file paths :)

# %% [markdown]
# ## Setup of dataset

# %%
from braindecode.datasets.combined import CombinedCntSets
from braindecode.mywyrm.processing import resample_cnt, bandpass_cnt, exponential_standardize_cnt

# %%
nico_C_sensors = ['FC5', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'FC6',
          'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'CP5', 'CP3', 'CP1', 'CPz',
          'CP2', 'CP4', 'CP6']
markers_10_class = {'1- Right Hand': [1], '2 - Left Hand': [2], '3 - Rest': [3],
           '4 - Feet': [4], '5 - Face': [5], '6 - Navigation': [6], '7 - Music': [7],
            '8 - Rotation': [8], '9 - Subtraction': [9], '10 - Words': [10]}

# %%
# Set args define one sequence per set: 
# filename, loader class (or 'bbci'), (i_first_trial, i_last_trial), (trial_start_ms, trial_end_ms),
# end marker dictionary
# trials up to before i_last_trial are contained, i_last_trial is not contained 
# end_marker_dictionary is only necessary if trial length is not fixed trial length
# it is a dictionary mapping start marker codes to end marker codes for all classes
# In case you have end marker definitions, trial end defines the offset to the end marker
# e.g. -500ms means 500ms before the trial end marker

set_args = (('data/robot-hall/NiRiNBD2S001R02_ds10_1-8.BBCI.mat',
                           'bbci', (0,600), (1500,4000), None),
          ('data/robot-hall/NiRiNBD2S001R02_ds10_1-8.BBCI.mat',
           'bbci', (600,800), (0,4000), None))
load_sensor_names = nico_C_sensors # In case you only want to load specific sensors, even before preprocessing 
sensor_names = nico_C_sensors # sensor names actually used for decoding, selected after preprocessing,
# useful in case you need a sensor during preprocessing which you do not want to use for decoding

# for preprocessing of continuous signal,
# define list of functions and arguments, functions will be applied one after the other:
cnt_preprocessors=((resample_cnt, dict(newfs=100)), # just to be faster in this tutorial :)
                   (bandpass_cnt, dict(low_cut_hz=4, high_cut_hz=None, filt_order=4)),
                   (exponential_standardize_cnt, dict())
                   )

marker_def=markers_10_class
dataset = CombinedCntSets(set_args=set_args,
                          load_sensor_names=load_sensor_names,
                          sensor_names=sensor_names,
                          cnt_preprocessors=cnt_preprocessors,
                          marker_def=marker_def
                         )

preprocessor = None # a later optional generic preprocessor for any time of dataset, not needed here

# %% [markdown]
# ### Setup of model

# %%
from braindecode.models.shallow_fbcsp import ShallowFBCSPNet

# %%
input_time_length = 750 # determines crops predicted simultaneously
model = ShallowFBCSPNet(in_chans=len(sensor_names), input_time_length=input_time_length,n_classes=10)
final_layer = model.get_layers()[-1]

# %%
### We can also print the layers
from braindecode.veganlasagne.layer_util import print_layers
print_layers(final_layer)
# Out:
#  0 InputLayer                                                         [None, 21, 750, 1]
#  1 DimshuffleLayer                                                    (None, 1, 750, 21)
#  2 Conv2DLayer              25x1                                      (None, 40, 726, 21)
#  3 Conv2DAllColsLayer       1x21                                      (None, 40, 726, 1)
#  4 BatchNormLayer                                     square
#  5 Pool2DLayer              75x1                      average_exc_pad (None, 40, 652, 1)
#  6 NonlinearityLayer                                  safe_log
#  7 StrideReshapeLayer           ::15 ::1                              (None, 40, 44, 1)
#  8 DropoutLayer
#  9 Conv2DLayer              30x1                                      (None, 10, 15, 1)
# 10 FinalReshapeLayer                                                  (None, 10)
# 11 NonlinearityLayer                                  softmax

# %% [markdown]
# ### Setup data splitting and iteration

# %%
# How to split the set into train valid and test
from braindecode.datahandling.splitters import SeveralSetsSplitter
from braindecode.veganlasagne.layers import get_n_sample_preds
# several sets splitter splits of the last set as a test set, 
# valid set fraction says what fraction of the training set is used for validation/early stopping
splitter = SeveralSetsSplitter(valid_set_fraction=0.2)

from braindecode.datahandling.batch_iteration import CntWindowTrialIterator
# iterator defines how to extract one training batch from the data
# CntWindowTrialIterator cut out crops of the trial as described in paper :)
# get n sample preds computes how many samples the Model above will predict
# in a single forward pass, i.e. input time length - receptive field + 1
iterator = CntWindowTrialIterator(batch_size=60, input_time_length=input_time_length,
                                 n_sample_preds=get_n_sample_preds(final_layer))

# %% [markdown]
# ### Setup experiment/optimization parameters

# %%
from lasagne.objectives import categorical_crossentropy
from lasagne.updates import adam
from braindecode.veganlasagne.stopping import MaxEpochs, NoDecrease, Or
from braindecode.veganlasagne.monitors import RuntimeMonitor, LossMonitor, MisclassMonitor, CntTrialMisclassMonitor
from braindecode.veganlasagne.update_modifiers import MaxNormConstraint
# Standard multi-class loss function
loss_expression = categorical_crossentropy
# how to compute updates given loss and params or grads and params
updates_expression = adam

# Modify updates which are computed by the updates expression
# Typically used to constrain weights for each layer to some norm
# (alternative to weight decay, which would be part of the loss function)
updates_modifier = MaxNormConstraint(default_norm=2.)

# Logging of expressions, both for output and to be used by early stopping
# note that the normal misclass monitor directly compared outputs and targets
# which in this case are predictions and labels for each sample, so we give it a different 
# channel name
# Loss, Misclass and CntTrialMisclass monitor automatically prepend the dataset name
# to the output, e.g., train_sample_misclass, valid_sample_misclass, ...
monitors = [LossMonitor(),MisclassMonitor(chan_name='sample_misclass'),
           CntTrialMisclassMonitor(input_time_length=input_time_length),
           RuntimeMonitor()]

# when to do the first stop, I usually do a combination of early stopping
# and a hard stop criterion (here with untypically small numbers):
stop_criterion = Or(stop_criteria=
                    (NoDecrease(chan_name='valid_misclass', num_epochs=15, min_decrease=0.),
                     MaxEpochs(25)))

# Which channel to use to select the best model after the early stop
remember_best_chan = 'valid_misclass'
run_after_early_stop = True # Could also just stop then without using validation part of training set
batch_modifier = None # object modifying a training batch, e.g., for online data augmentation

# %% [markdown]
# ### Setup and run the experiment

# %%
from braindecode.experiments.experiment import Experiment

# %%
exp = Experiment(final_layer, dataset=dataset, splitter=splitter, preprocessor=preprocessor,
          iterator=iterator, loss_expression=loss_expression,
          updates_expression=updates_expression, updates_modifier=updates_modifier,
          monitors=monitors, stop_criterion=stop_criterion, remember_best_chan=remember_best_chan,
          run_after_early_stop=run_after_early_stop, batch_modifier=batch_modifier)

# %%
# yes it loads both twice, once for train and once for set... but still fast enough IMO :D
exp.setup() # also resets lasagnes random generator.
# Out:
# INFO:braindecode.datasets.combined:Loading set 1 of 2
# INFO:braindecode.datasets.cnt_signal_matrix:Load continuous signal...
# INFO:braindecode.datasets.cnt_signal_matrix:Preprocess continuous signal...
# INFO:braindecode.mywyrm.processing:Using highpass filter since high cut hz is None
# INFO:braindecode.datasets.cnt_signal_matrix:Loaded dataset with shape: (454370, 21, 1, 1)
# INFO:braindecode.datasets.combined:Loading set 2 of 2
# INFO:braindecode.datasets.cnt_signal_matrix:Load continuous signal...
# INFO:braindecode.datasets.cnt_signal_matrix:Preprocess continuous signal...
# INFO:braindecode.mywyrm.processing:Using highpass filter since high cut hz is None
# INFO:braindecode.datasets.cnt_signal_matrix:Loaded dataset with shape: (151296, 21, 1, 1)
# INFO:braindecode.experiments.experiment:Layers...
# INFO:braindecode.experiments.experiment:
#  0 InputLayer                                                         [None, 21, 750, 1]
#  1 DimshuffleLayer                                                    (None, 1, 750, 21)
#  2 Conv2DLayer              25x1                                      (None, 40, 726, 21)
#  3 Conv2DAllColsLayer       1x21                                      (None, 40, 726, 1)
#  4 BatchNormLayer                                     square
#  5 Pool2DLayer              75x1                      average_exc_pad (None, 40, 652, 1)
#  6 NonlinearityLayer                                  safe_log
#  7 StrideReshapeLayer           ::15 ::1                              (None, 40, 44, 1)
#  8 DropoutLayer
#  9 Conv2DLayer              30x1                                      (None, 10, 15, 1)
# 10 FinalReshapeLayer                                                  (None, 10)
# 11 NonlinearityLayer                                  softmax
#
# INFO:braindecode.experiments.experiment:Create theano functions...
# INFO:braindecode.veganlasagne.update_modifiers:Constraining time_conv to norm 2.00
# INFO:braindecode.veganlasagne.update_modifiers:Constraining spat_conv to norm 2.00
# INFO:braindecode.veganlasagne.update_modifiers:Constraining final_dense to norm 2.00
# INFO:braindecode.experiments.experiment:Done.

# %%
exp.run()
# Out:
# INFO:braindecode.experiments.experiment:Run until first stop...
# INFO:braindecode.experiments.experiment:Split/Preprocess datasets...
# INFO:braindecode.experiments.experiment:...Done
# INFO:braindecode.experiments.experiment:Epoch 0
# INFO:braindecode.experiments.experiment:train_loss                9.40613
# INFO:braindecode.experiments.experiment:valid_loss                9.55397
# INFO:braindecode.experiments.experiment:test_loss                 9.40684
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.90149
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.89831
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.89950
# INFO:braindecode.experiments.experiment:train_misclass            0.90149
# INFO:braindecode.experiments.experiment:valid_misclass            0.89831
# INFO:braindecode.experiments.experiment:test_misclass             0.89950
# INFO:braindecode.experiments.experiment:runtime                   0.00000
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.898305
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.437018 seconds
# INFO:braindecode.experiments.experiment:Epoch 1
# INFO:braindecode.experiments.experiment:train_loss                2.65924
# INFO:braindecode.experiments.experiment:valid_loss                2.85296
# INFO:braindecode.experiments.experiment:test_loss                 3.22533
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.77563
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.81938
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.84721
# INFO:braindecode.experiments.experiment:train_misclass            0.74349
# INFO:braindecode.experiments.experiment:valid_misclass            0.79661
# INFO:braindecode.experiments.experiment:test_misclass             0.84422
# INFO:braindecode.experiments.experiment:runtime                   2.69678
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.796610
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.403192 seconds
# INFO:braindecode.experiments.experiment:Epoch 2
# INFO:braindecode.experiments.experiment:train_loss                1.63539
# INFO:braindecode.experiments.experiment:valid_loss                1.91405
# INFO:braindecode.experiments.experiment:test_loss                 2.31591
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.56979
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.69601
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.81115
# INFO:braindecode.experiments.experiment:train_misclass            0.52416
# INFO:braindecode.experiments.experiment:valid_misclass            0.64407
# INFO:braindecode.experiments.experiment:test_misclass             0.80402
# INFO:braindecode.experiments.experiment:runtime                   2.59406
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.644068
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.499165 seconds
# INFO:braindecode.experiments.experiment:Epoch 3
# INFO:braindecode.experiments.experiment:train_loss                1.43490
# INFO:braindecode.experiments.experiment:valid_loss                1.79387
# INFO:braindecode.experiments.experiment:test_loss                 2.32931
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.48145
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.66578
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.81631
# INFO:braindecode.experiments.experiment:train_misclass            0.39219
# INFO:braindecode.experiments.experiment:valid_misclass            0.62712
# INFO:braindecode.experiments.experiment:test_misclass             0.78894
# INFO:braindecode.experiments.experiment:runtime                   2.67487
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.627119
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.403282 seconds
# INFO:braindecode.experiments.experiment:Epoch 4
# INFO:braindecode.experiments.experiment:train_loss                1.24175
# INFO:braindecode.experiments.experiment:valid_loss                1.71958
# INFO:braindecode.experiments.experiment:test_loss                 2.25677
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.36502
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.65938
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.78915
# INFO:braindecode.experiments.experiment:train_misclass            0.25279
# INFO:braindecode.experiments.experiment:valid_misclass            0.61017
# INFO:braindecode.experiments.experiment:test_misclass             0.75879
# INFO:braindecode.experiments.experiment:runtime                   2.57737
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.610169
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.408827 seconds
# INFO:braindecode.experiments.experiment:Epoch 5
# INFO:braindecode.experiments.experiment:train_loss                1.10373
# INFO:braindecode.experiments.experiment:valid_loss                1.68623
# INFO:braindecode.experiments.experiment:test_loss                 2.28113
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.30505
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.62028
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.78568
# INFO:braindecode.experiments.experiment:train_misclass            0.19703
# INFO:braindecode.experiments.experiment:valid_misclass            0.59322
# INFO:braindecode.experiments.experiment:test_misclass             0.75879
# INFO:braindecode.experiments.experiment:runtime                   2.59034
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.593220
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.419140 seconds
# INFO:braindecode.experiments.experiment:Epoch 6
# INFO:braindecode.experiments.experiment:train_loss                0.99166
# INFO:braindecode.experiments.experiment:valid_loss                1.75410
# INFO:braindecode.experiments.experiment:test_loss                 2.25305
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.27720
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.67059
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.76938
# INFO:braindecode.experiments.experiment:train_misclass            0.19145
# INFO:braindecode.experiments.experiment:valid_misclass            0.61017
# INFO:braindecode.experiments.experiment:test_misclass             0.70352
# INFO:braindecode.experiments.experiment:runtime                   2.60288
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.407397 seconds
# INFO:braindecode.experiments.experiment:Epoch 7
# INFO:braindecode.experiments.experiment:train_loss                0.87769
# INFO:braindecode.experiments.experiment:valid_loss                1.73061
# INFO:braindecode.experiments.experiment:test_loss                 2.23939
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.22247
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.63911
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.75866
# INFO:braindecode.experiments.experiment:train_misclass            0.12639
# INFO:braindecode.experiments.experiment:valid_misclass            0.61017
# INFO:braindecode.experiments.experiment:test_misclass             0.71859
# INFO:braindecode.experiments.experiment:runtime                   2.58451
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.408198 seconds
# INFO:braindecode.experiments.experiment:Epoch 8
# INFO:braindecode.experiments.experiment:train_loss                0.78809
# INFO:braindecode.experiments.experiment:valid_loss                1.70403
# INFO:braindecode.experiments.experiment:test_loss                 2.34558
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.19271
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.64661
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.75930
# INFO:braindecode.experiments.experiment:train_misclass            0.10223
# INFO:braindecode.experiments.experiment:valid_misclass            0.57627
# INFO:braindecode.experiments.experiment:test_misclass             0.70352
# INFO:braindecode.experiments.experiment:runtime                   2.59095
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.576271
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.406946 seconds
# INFO:braindecode.experiments.experiment:Epoch 9
# INFO:braindecode.experiments.experiment:train_loss                0.71940
# INFO:braindecode.experiments.experiment:valid_loss                1.73609
# INFO:braindecode.experiments.experiment:test_loss                 2.34269
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.16340
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.63419
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.75648
# INFO:braindecode.experiments.experiment:train_misclass            0.07993
# INFO:braindecode.experiments.experiment:valid_misclass            0.57627
# INFO:braindecode.experiments.experiment:test_misclass             0.68342
# INFO:braindecode.experiments.experiment:runtime                   2.59182
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.576271
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.404668 seconds
# INFO:braindecode.experiments.experiment:Epoch 10
# INFO:braindecode.experiments.experiment:train_loss                0.61789
# INFO:braindecode.experiments.experiment:valid_loss                1.63412
# INFO:braindecode.experiments.experiment:test_loss                 2.29070
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.12002
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.62220
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.75802
# INFO:braindecode.experiments.experiment:train_misclass            0.04275
# INFO:braindecode.experiments.experiment:valid_misclass            0.54237
# INFO:braindecode.experiments.experiment:test_misclass             0.64322
# INFO:braindecode.experiments.experiment:runtime                   2.58097
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.542373
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.403692 seconds
# INFO:braindecode.experiments.experiment:Epoch 11
# INFO:braindecode.experiments.experiment:train_loss                0.57437
# INFO:braindecode.experiments.experiment:valid_loss                1.68273
# INFO:braindecode.experiments.experiment:test_loss                 2.42519
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.11693
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.61489
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.76771
# INFO:braindecode.experiments.experiment:train_misclass            0.04833
# INFO:braindecode.experiments.experiment:valid_misclass            0.59322
# INFO:braindecode.experiments.experiment:test_misclass             0.70854
# INFO:braindecode.experiments.experiment:runtime                   2.57754
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.406427 seconds
# INFO:braindecode.experiments.experiment:Epoch 12
# INFO:braindecode.experiments.experiment:train_loss                0.48367
# INFO:braindecode.experiments.experiment:valid_loss                1.64395
# INFO:braindecode.experiments.experiment:test_loss                 2.30383
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.07757
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.58131
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.74093
# INFO:braindecode.experiments.experiment:train_misclass            0.01859
# INFO:braindecode.experiments.experiment:valid_misclass            0.50847
# INFO:braindecode.experiments.experiment:test_misclass             0.62814
# INFO:braindecode.experiments.experiment:runtime                   2.58325
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.508475
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.407643 seconds
# INFO:braindecode.experiments.experiment:Epoch 13
# INFO:braindecode.experiments.experiment:train_loss                0.43364
# INFO:braindecode.experiments.experiment:valid_loss                1.63821
# INFO:braindecode.experiments.experiment:test_loss                 2.37230
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.07475
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.59080
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.73761
# INFO:braindecode.experiments.experiment:train_misclass            0.01673
# INFO:braindecode.experiments.experiment:valid_misclass            0.50847
# INFO:braindecode.experiments.experiment:test_misclass             0.64322
# INFO:braindecode.experiments.experiment:runtime                   2.59417
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.508475
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.400462 seconds
# INFO:braindecode.experiments.experiment:Epoch 14
# INFO:braindecode.experiments.experiment:train_loss                0.37792
# INFO:braindecode.experiments.experiment:valid_loss                1.63352
# INFO:braindecode.experiments.experiment:test_loss                 2.40373
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.04836
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.60814
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.75955
# INFO:braindecode.experiments.experiment:train_misclass            0.00186
# INFO:braindecode.experiments.experiment:valid_misclass            0.57627
# INFO:braindecode.experiments.experiment:test_misclass             0.67839
# INFO:braindecode.experiments.experiment:runtime                   2.57678
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.406571 seconds
# INFO:braindecode.experiments.experiment:Epoch 15
# INFO:braindecode.experiments.experiment:train_loss                0.33963
# INFO:braindecode.experiments.experiment:valid_loss                1.65778
# INFO:braindecode.experiments.experiment:test_loss                 2.49701
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.04726
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.60892
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.75925
# INFO:braindecode.experiments.experiment:train_misclass            0.01115
# INFO:braindecode.experiments.experiment:valid_misclass            0.55932
# INFO:braindecode.experiments.experiment:test_misclass             0.69849
# INFO:braindecode.experiments.experiment:runtime                   2.57837
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.405378 seconds
# INFO:braindecode.experiments.experiment:Epoch 16
# INFO:braindecode.experiments.experiment:train_loss                0.31990
# INFO:braindecode.experiments.experiment:valid_loss                1.65236
# INFO:braindecode.experiments.experiment:test_loss                 2.48441
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.03678
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.60736
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.75069
# INFO:braindecode.experiments.experiment:train_misclass            0.00186
# INFO:braindecode.experiments.experiment:valid_misclass            0.55932
# INFO:braindecode.experiments.experiment:test_misclass             0.66834
# INFO:braindecode.experiments.experiment:runtime                   2.58122
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.406718 seconds
# INFO:braindecode.experiments.experiment:Epoch 17
# INFO:braindecode.experiments.experiment:train_loss                0.29509
# INFO:braindecode.experiments.experiment:valid_loss                1.75849
# INFO:braindecode.experiments.experiment:test_loss                 2.43800
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.03530
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.58959
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.73683
# INFO:braindecode.experiments.experiment:train_misclass            0.00929
# INFO:braindecode.experiments.experiment:valid_misclass            0.54237
# INFO:braindecode.experiments.experiment:test_misclass             0.65829
# INFO:braindecode.experiments.experiment:runtime                   2.58593
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.413841 seconds
# INFO:braindecode.experiments.experiment:Epoch 18
# INFO:braindecode.experiments.experiment:train_loss                0.25571
# INFO:braindecode.experiments.experiment:valid_loss                1.71011
# INFO:braindecode.experiments.experiment:test_loss                 2.52627
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.02998
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.57807
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.74043
# INFO:braindecode.experiments.experiment:train_misclass            0.00186
# INFO:braindecode.experiments.experiment:valid_misclass            0.52542
# INFO:braindecode.experiments.experiment:test_misclass             0.69849
# INFO:braindecode.experiments.experiment:runtime                   2.58909
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.401839 seconds
# INFO:braindecode.experiments.experiment:Epoch 19
# INFO:braindecode.experiments.experiment:train_loss                0.24250
# INFO:braindecode.experiments.experiment:valid_loss                1.74514
# INFO:braindecode.experiments.experiment:test_loss                 2.56749
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.03201
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.56077
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.74082
# INFO:braindecode.experiments.experiment:train_misclass            0.00372
# INFO:braindecode.experiments.experiment:valid_misclass            0.50847
# INFO:braindecode.experiments.experiment:test_misclass             0.67337
# INFO:braindecode.experiments.experiment:runtime                   2.57765
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.508475
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.440991 seconds
# INFO:braindecode.experiments.experiment:Epoch 20
# INFO:braindecode.experiments.experiment:train_loss                0.21532
# INFO:braindecode.experiments.experiment:valid_loss                1.77475
# INFO:braindecode.experiments.experiment:test_loss                 2.46981
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.02423
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.60595
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.73143
# INFO:braindecode.experiments.experiment:train_misclass            0.00000
# INFO:braindecode.experiments.experiment:valid_misclass            0.55932
# INFO:braindecode.experiments.experiment:test_misclass             0.66332
# INFO:braindecode.experiments.experiment:runtime                   2.61468
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.404892 seconds
# INFO:braindecode.experiments.experiment:Epoch 21
# INFO:braindecode.experiments.experiment:train_loss                0.19071
# INFO:braindecode.experiments.experiment:valid_loss                1.82775
# INFO:braindecode.experiments.experiment:test_loss                 2.56411
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.01818
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.59904
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.74371
# INFO:braindecode.experiments.experiment:train_misclass            0.00000
# INFO:braindecode.experiments.experiment:valid_misclass            0.62712
# INFO:braindecode.experiments.experiment:test_misclass             0.66332
# INFO:braindecode.experiments.experiment:runtime                   2.57659
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.405252 seconds
# INFO:braindecode.experiments.experiment:Epoch 22
# INFO:braindecode.experiments.experiment:train_loss                0.18802
# INFO:braindecode.experiments.experiment:valid_loss                1.89812
# INFO:braindecode.experiments.experiment:test_loss                 2.57312
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.01976
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.63852
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.74232
# INFO:braindecode.experiments.experiment:train_misclass            0.00000
# INFO:braindecode.experiments.experiment:valid_misclass            0.64407
# INFO:braindecode.experiments.experiment:test_misclass             0.69849
# INFO:braindecode.experiments.experiment:runtime                   2.57238
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.402512 seconds
# INFO:braindecode.experiments.experiment:Epoch 23
# INFO:braindecode.experiments.experiment:train_loss                0.16832
# INFO:braindecode.experiments.experiment:valid_loss                1.72376
# INFO:braindecode.experiments.experiment:test_loss                 2.70449
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.01453
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.57151
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.75713
# INFO:braindecode.experiments.experiment:train_misclass            0.00000
# INFO:braindecode.experiments.experiment:valid_misclass            0.50847
# INFO:braindecode.experiments.experiment:test_misclass             0.70854
# INFO:braindecode.experiments.experiment:runtime                   2.57778
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.veganlasagne.remember:New best valid_misclass: 0.508475
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.406901 seconds
# INFO:braindecode.experiments.experiment:Epoch 24
# INFO:braindecode.experiments.experiment:train_loss                0.15925
# INFO:braindecode.experiments.experiment:valid_loss                1.89095
# INFO:braindecode.experiments.experiment:test_loss                 2.76979
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.01421
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.60912
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.75357
# INFO:braindecode.experiments.experiment:train_misclass            0.00000
# INFO:braindecode.experiments.experiment:valid_misclass            0.57627
# INFO:braindecode.experiments.experiment:test_misclass             0.69347
# INFO:braindecode.experiments.experiment:runtime                   2.58590
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.403012 seconds
# INFO:braindecode.experiments.experiment:Epoch 25
# INFO:braindecode.experiments.experiment:train_loss                0.15014
# INFO:braindecode.experiments.experiment:valid_loss                1.83531
# INFO:braindecode.experiments.experiment:test_loss                 2.65717
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.01207
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.59666
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.74789
# INFO:braindecode.experiments.experiment:train_misclass            0.00186
# INFO:braindecode.experiments.experiment:valid_misclass            0.54237
# INFO:braindecode.experiments.experiment:test_misclass             0.68342
# INFO:braindecode.experiments.experiment:runtime                   2.57704
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Setup for second stop...
# INFO:braindecode.experiments.experiment:Train loss to reach 0.16832
# INFO:braindecode.experiments.experiment:Run until second stop...
# INFO:braindecode.experiments.experiment:Epoch 24
# INFO:braindecode.experiments.experiment:train_loss                0.32772
# INFO:braindecode.experiments.experiment:valid_loss                1.72376
# INFO:braindecode.experiments.experiment:test_loss                 2.70449
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.07266
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.57151
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.75713
# INFO:braindecode.experiments.experiment:train_misclass            0.05342
# INFO:braindecode.experiments.experiment:valid_misclass            0.50847
# INFO:braindecode.experiments.experiment:test_misclass             0.70854
# INFO:braindecode.experiments.experiment:runtime                   1.19036
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.564575 seconds
# INFO:braindecode.experiments.experiment:Epoch 25
# INFO:braindecode.experiments.experiment:train_loss                0.29840
# INFO:braindecode.experiments.experiment:valid_loss                0.87170
# INFO:braindecode.experiments.experiment:test_loss                 2.58650
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.05933
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.30204
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.73967
# INFO:braindecode.experiments.experiment:train_misclass            0.02671
# INFO:braindecode.experiments.experiment:valid_misclass            0.18644
# INFO:braindecode.experiments.experiment:test_misclass             0.69849
# INFO:braindecode.experiments.experiment:runtime                   2.83599
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.574823 seconds
# INFO:braindecode.experiments.experiment:Epoch 26
# INFO:braindecode.experiments.experiment:train_loss                0.23561
# INFO:braindecode.experiments.experiment:valid_loss                0.63613
# INFO:braindecode.experiments.experiment:test_loss                 2.59143
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.03553
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.17902
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.73969
# INFO:braindecode.experiments.experiment:train_misclass            0.01336
# INFO:braindecode.experiments.experiment:valid_misclass            0.11864
# INFO:braindecode.experiments.experiment:test_misclass             0.68844
# INFO:braindecode.experiments.experiment:runtime                   2.84264
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.573273 seconds
# INFO:braindecode.experiments.experiment:Epoch 27
# INFO:braindecode.experiments.experiment:train_loss                0.24433
# INFO:braindecode.experiments.experiment:valid_loss                0.55586
# INFO:braindecode.experiments.experiment:test_loss                 2.64657
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.04044
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.14344
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.73052
# INFO:braindecode.experiments.experiment:train_misclass            0.00668
# INFO:braindecode.experiments.experiment:valid_misclass            0.05085
# INFO:braindecode.experiments.experiment:test_misclass             0.67839
# INFO:braindecode.experiments.experiment:runtime                   2.84638
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.575177 seconds
# INFO:braindecode.experiments.experiment:Epoch 28
# INFO:braindecode.experiments.experiment:train_loss                0.19699
# INFO:braindecode.experiments.experiment:valid_loss                0.41949
# INFO:braindecode.experiments.experiment:test_loss                 2.55518
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.02553
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.10134
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.72164
# INFO:braindecode.experiments.experiment:train_misclass            0.00501
# INFO:braindecode.experiments.experiment:valid_misclass            0.03390
# INFO:braindecode.experiments.experiment:test_misclass             0.64824
# INFO:braindecode.experiments.experiment:runtime                   2.84691
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.580656 seconds
# INFO:braindecode.experiments.experiment:Epoch 29
# INFO:braindecode.experiments.experiment:train_loss                0.18829
# INFO:braindecode.experiments.experiment:valid_loss                0.38396
# INFO:braindecode.experiments.experiment:test_loss                 2.63978
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.02102
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.06955
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.73609
# INFO:braindecode.experiments.experiment:train_misclass            0.00167
# INFO:braindecode.experiments.experiment:valid_misclass            0.00000
# INFO:braindecode.experiments.experiment:test_misclass             0.70352
# INFO:braindecode.experiments.experiment:runtime                   2.85162
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.581557 seconds
# INFO:braindecode.experiments.experiment:Epoch 30
# INFO:braindecode.experiments.experiment:train_loss                0.16659
# INFO:braindecode.experiments.experiment:valid_loss                0.32266
# INFO:braindecode.experiments.experiment:test_loss                 2.59649
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.01741
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.05870
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.72614
# INFO:braindecode.experiments.experiment:train_misclass            0.00167
# INFO:braindecode.experiments.experiment:valid_misclass            0.01695
# INFO:braindecode.experiments.experiment:test_misclass             0.68342
# INFO:braindecode.experiments.experiment:runtime                   2.85069
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.575573 seconds
# INFO:braindecode.experiments.experiment:Epoch 31
# INFO:braindecode.experiments.experiment:train_loss                0.17120
# INFO:braindecode.experiments.experiment:valid_loss                0.33549
# INFO:braindecode.experiments.experiment:test_loss                 2.60299
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.01651
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.06120
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.74744
# INFO:braindecode.experiments.experiment:train_misclass            0.00000
# INFO:braindecode.experiments.experiment:valid_misclass            0.00000
# INFO:braindecode.experiments.experiment:test_misclass             0.72362
# INFO:braindecode.experiments.experiment:runtime                   2.84534
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.582846 seconds
# INFO:braindecode.experiments.experiment:Epoch 32
# INFO:braindecode.experiments.experiment:train_loss                0.16134
# INFO:braindecode.experiments.experiment:valid_loss                0.28423
# INFO:braindecode.experiments.experiment:test_loss                 2.58502
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.01623
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.05342
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.72641
# INFO:braindecode.experiments.experiment:train_misclass            0.00334
# INFO:braindecode.experiments.experiment:valid_misclass            0.03390
# INFO:braindecode.experiments.experiment:test_misclass             0.65829
# INFO:braindecode.experiments.experiment:runtime                   2.85171
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.585605 seconds
# INFO:braindecode.experiments.experiment:Epoch 33
# INFO:braindecode.experiments.experiment:train_loss                0.14272
# INFO:braindecode.experiments.experiment:valid_loss                0.27036
# INFO:braindecode.experiments.experiment:test_loss                 2.53785
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.01099
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.04655
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.72603
# INFO:braindecode.experiments.experiment:train_misclass            0.00167
# INFO:braindecode.experiments.experiment:valid_misclass            0.01695
# INFO:braindecode.experiments.experiment:test_misclass             0.67839
# INFO:braindecode.experiments.experiment:runtime                   2.86009
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.577349 seconds
# INFO:braindecode.experiments.experiment:Epoch 34
# INFO:braindecode.experiments.experiment:train_loss                0.13689
# INFO:braindecode.experiments.experiment:valid_loss                0.21340
# INFO:braindecode.experiments.experiment:test_loss                 2.56156
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.00921
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.02499
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.72005
# INFO:braindecode.experiments.experiment:train_misclass            0.00000
# INFO:braindecode.experiments.experiment:valid_misclass            0.00000
# INFO:braindecode.experiments.experiment:test_misclass             0.66834
# INFO:braindecode.experiments.experiment:runtime                   2.84978
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.580473 seconds
# INFO:braindecode.experiments.experiment:Epoch 35
# INFO:braindecode.experiments.experiment:train_loss                0.13324
# INFO:braindecode.experiments.experiment:valid_loss                0.23774
# INFO:braindecode.experiments.experiment:test_loss                 2.64305
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.00914
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.03167
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.73563
# INFO:braindecode.experiments.experiment:train_misclass            0.00000
# INFO:braindecode.experiments.experiment:valid_misclass            0.00000
# INFO:braindecode.experiments.experiment:test_misclass             0.68342
# INFO:braindecode.experiments.experiment:runtime                   2.84648
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.579215 seconds
# INFO:braindecode.experiments.experiment:Epoch 36
# INFO:braindecode.experiments.experiment:train_loss                0.13026
# INFO:braindecode.experiments.experiment:valid_loss                0.21123
# INFO:braindecode.experiments.experiment:test_loss                 2.53807
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.00821
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.02753
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.72204
# INFO:braindecode.experiments.experiment:train_misclass            0.00000
# INFO:braindecode.experiments.experiment:valid_misclass            0.00000
# INFO:braindecode.experiments.experiment:test_misclass             0.67337
# INFO:braindecode.experiments.experiment:runtime                   2.85067
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.585067 seconds
# INFO:braindecode.experiments.experiment:Epoch 37
# INFO:braindecode.experiments.experiment:train_loss                0.11957
# INFO:braindecode.experiments.experiment:valid_loss                0.20107
# INFO:braindecode.experiments.experiment:test_loss                 2.58656
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.00682
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.01910
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.73485
# INFO:braindecode.experiments.experiment:train_misclass            0.00000
# INFO:braindecode.experiments.experiment:valid_misclass            0.00000
# INFO:braindecode.experiments.experiment:test_misclass             0.65327
# INFO:braindecode.experiments.experiment:runtime                   2.85897
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.583890 seconds
# INFO:braindecode.experiments.experiment:Epoch 38
# INFO:braindecode.experiments.experiment:train_loss                0.12371
# INFO:braindecode.experiments.experiment:valid_loss                0.20106
# INFO:braindecode.experiments.experiment:test_loss                 2.59510
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.00746
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.02011
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.72861
# INFO:braindecode.experiments.experiment:train_misclass            0.00000
# INFO:braindecode.experiments.experiment:valid_misclass            0.00000
# INFO:braindecode.experiments.experiment:test_misclass             0.67839
# INFO:braindecode.experiments.experiment:runtime                   2.85526
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.575063 seconds
# INFO:braindecode.experiments.experiment:Epoch 39
# INFO:braindecode.experiments.experiment:train_loss                0.12070
# INFO:braindecode.experiments.experiment:valid_loss                0.21215
# INFO:braindecode.experiments.experiment:test_loss                 2.55975
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.00756
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.03034
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.72908
# INFO:braindecode.experiments.experiment:train_misclass            0.00000
# INFO:braindecode.experiments.experiment:valid_misclass            0.00000
# INFO:braindecode.experiments.experiment:test_misclass             0.65327
# INFO:braindecode.experiments.experiment:runtime                   2.85106
# INFO:braindecode.experiments.experiment:
# INFO:braindecode.experiments.experiment:Time updates following epoch: 1.593245 seconds
# INFO:braindecode.experiments.experiment:Epoch 40
# INFO:braindecode.experiments.experiment:train_loss                0.10450
# INFO:braindecode.experiments.experiment:valid_loss                0.15573
# INFO:braindecode.experiments.experiment:test_loss                 2.55001
# INFO:braindecode.experiments.experiment:train_sample_misclass     0.00557
# INFO:braindecode.experiments.experiment:valid_sample_misclass     0.01293
# INFO:braindecode.experiments.experiment:test_sample_misclass      0.72436
# INFO:braindecode.experiments.experiment:train_misclass            0.00000
# INFO:braindecode.experiments.experiment:valid_misclass            0.00000
# INFO:braindecode.experiments.experiment:test_misclass             0.65829
# INFO:braindecode.experiments.experiment:runtime                   2.85486
# INFO:braindecode.experiments.experiment:

# %% [markdown]
# ## With Config-File

# %% [markdown]
# Now we can run some similar experiments with a yaml-config file.

# %% [markdown]
# #### The config file
# This is the config file :) It uses yaml plus dollar-variables to define templates and parameters. it is a bit hacky :) Possibly it should be replaced by https://github.com/IDSIA/sacred one day :)

# %%
# %load configs/experiments/tutorial/shallow_net_online.yaml
{
    templates: {
        resample_bandpass_standardize: 
        [[
                # !!python/name:braindecode.mywyrm.processing.resample_cnt , 
                {'newfs': $resample_fs},
            ],
            [
                # !!python/name:braindecode.mywyrm.processing.bandpass_cnt , 
                {'low_cut_hz': $low_cut_off_hz,
                'high_cut_hz': $high_cut_hz,
                filt_order: $filt_order}
        ],
            [
                # !!python/name:braindecode.mywyrm.processing.exponential_standardize_cnt , 
                { }
        ],
            ],
        combined_cnt_set: !obj:braindecode.datasets.combined.CombinedCntSets {
            set_args: !!python/object/apply:zip [
                $filenames, $set_types, 
                $trial_ranges, $all_segment_ivals, $end_marker_defs],
            load_sensor_names: $load_sensor_names,
            sensor_names: $sensor_names,
            marker_def: $marker_def,
            cnt_preprocessors: $cnt_preprocessors,
        },
        # not used 
        # end_markers_movement_class: {'01 - Right Hand': [5], 
        #'02 - Left Hand': [6], '03 - Rest': [7],
        #   '04 - Feet': [8},
        markers_10_class: {'1- Right Hand': [1], '2 - Left Hand': [2], '3 - Rest': [3],
           '4 - Feet': [4], '5 - Face': [5], '6 - Navigation': [6], '7 - Music': [7],
            '8 - Rotation': [8], '9 - Subtraction': [9], '10 - Words': [10] },
        markers_movement_class:  {'01 - Right Hand': [1], '02 - Left Hand': [2], '03 - Rest': [3],
           '04 - Feet': [4]},
         nico_C_sensors: ['FC5', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'FC6',
          'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'CP5', 'CP3', 'CP1', 'CPz',
          'CP2', 'CP4', 'CP6'],
          # in_sensors will be replaced automatically 
          shallow_net: !obj:braindecode.models.shallow_fbcsp.ShallowFBCSPNet {
            in_chans: in_sensors,
            input_time_length: $input_time_length,
            n_classes: $n_classes,
          },
          several_sets_splitter: !obj:braindecode.datahandling.splitters.SeveralSetsSplitter {
            use_test_as_valid: $use_test_as_valid,
            valid_set_fraction: $valid_set_fraction,
        },
        cnt_iterator: !obj:braindecode.datahandling.batch_iteration.CntWindowTrialIterator {
            batch_size: $batch_size,
            input_time_length: $input_time_length,
            n_sample_preds: $n_sample_preds,
        },
        sample_trial_monitors: [
                # !obj:braindecode.veganlasagne.monitors.LossMonitor {},
                # !obj:braindecode.veganlasagne.monitors.MisclassMonitor {
                    chan_name: 'sample_misclass'},
                # !obj:braindecode.veganlasagne.monitors.CntTrialMisclassMonitor { 
                    input_time_length: $input_time_length},
                # !obj:braindecode.veganlasagne.monitors.RuntimeMonitor {},
        ],
        categorical_crossentropy: !!python/name:lasagne.objectives.categorical_crossentropy ,
        adam: !!python/name:lasagne.updates.adam ,
        max_norm_modifier: !obj:braindecode.veganlasagne.update_modifiers.MaxNormConstraint {
            default_norm: $default_norm,
        },
       
    },
    variants: [[{ 
        # where results will be saved
        save_path: ['data/models/online/tutorial/'],
        
        filenames: [[  
                'data/robot-hall/NiRiNBD2S001R02_ds10_1-8.BBCI.mat',
                'data/robot-hall/NiRiNBD2S001R02_ds10_1-8.BBCI.mat',
        ]],
        set_types: [[
            'bbci',
            'bbci',
        ]],
        all_segment_ivals: [[
            [1500, 4500],
            [0, 4000],
            ],
        ],
        # no end markers
        end_marker_defs: ["[ 
                null,
                null,
        ]"],
        load_sensor_names: [$nico_C_sensors],
        sensor_names: [$nico_C_sensors],
        cnt_preprocessors: [$resample_bandpass_standardize],
        resample_fs: [250],
        
        # try both 0 and 4
        low_cut_off_hz: [0,4],
        high_cut_hz: ['null'],
        filt_order: [4],
        
        dataset: [$combined_cnt_set],
        dataset_splitter: [$several_sets_splitter],
        
        preprocessor: ['null'],
        
        layers: [$shallow_net],
        input_time_length: [750],
        
        valid_set_fraction: [0.2],
        use_test_as_valid: [False],
        
        batch_size: [60],
        n_sample_preds: [200], # will be replaced automatically
        
        iterator: [$cnt_iterator],
        monitors: [$sample_trial_monitors],

        loss_expression: [$categorical_crossentropy],
        updates_expression: [$adam],
        updates_modifier: [$max_norm_modifier],
        default_norm: [2.],

        early_stop_chan: ['valid_misclass'],
        max_increasing_epochs: [15],
        max_epochs: [25],
        run_after_early_stop: [true],
        batch_modifier: ['null'],
        variants: [[
        # with 10 classes
        {
            # null indicates till end
            trial_ranges: [
            "[[0,600], [600,null]]"
            ],
            marker_def: [$markers_10_class],
            n_classes: [10],
        }, 
        # with only movement classes,
        # adjust trial ranges...
        {
            trial_ranges: [
            "[[0,300], [300,null]]"
            ],
            marker_def: [$markers_movement_class],
            n_classes: [4],
        }]],
        # not used but needs to be given
        num_cv_folds: [-1],
        
    }]],
}

# %% [markdown]
# To run this config file run this in the terminal, in the braindecode folder:
#
# ```./scripts/train_experiments.py configs/experiments/tutorial/shallow_net_online.yaml```
#
# You can also run specific experiments
#
# ```./scripts/train_experiments.py configs/experiments/tutorial/shallow_net_online.yaml --start 1 --stop 1
# ./scripts/train_experiments.py configs/experiments/tutorial/shallow_net_online.yaml --start 2 --stop 4```
#
# etc.

# %% [markdown]
# In the config directory you can see a lot of config fiels with more advanced usages like extending other config files etc.

# %% [markdown]
# ### Analyzing experiments run this way

# %%
from braindecode.analysis.pandas_util import load_data_frame, remove_columns_with_same_value

# %%
remove_columns_with_same_value(load_data_frame('data/models/tutorial/online/'))
# Out:
#                marker_def           trial_ranges  low_cut_off_hz  n_classes  \
# 1        markers_10_class  [[0,600], [600,null]]               0         10
# 4        markers_10_class  [[0,600], [600,null]]               4         10
# 5  markers_movement_class  [[0,300], [300,null]]               0          4
# 6  markers_movement_class  [[0,300], [300,null]]               4          4
#
#       time       test  test_sample       train  train_sample
# 1 00:05:02  36.683417    29.750596   99.332220     93.052168
# 4 00:04:46  36.180905    28.121251   99.332220     92.623843
# 5 00:02:11  57.894737    48.847926   98.662207     93.032458
# 6 00:02:17  52.631579    41.993694  100.000000     97.162970

# %% [markdown]
# ## Stuff just for me (Robin) :)

# %%
# %%capture
import scikits.samplerate
import os
import site
site.addsitedir('/home/schirrmr/.local/lib/python2.7/site-packages/')
site.addsitedir('/usr/lib/pymodules/python2.7/')
os.sys.path.insert(0, '/home/schirrmr/braindecode/code/')
# %cd /home/schirrmr/braindecode/code/braindecode/
assert 'THEANO_FLAGS' in os.environ
# switch to cpu
#os.environ['THEANO_FLAGS'] = 'floatX=float32,device=cpu,nvcc.fastmath=True'
